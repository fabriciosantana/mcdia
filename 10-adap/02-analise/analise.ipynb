# %%
# %pip install distance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for distance: filename=distance-0.1.3-py3-none-any.whl size=16321 sha256=9fe56eb6072d23e7e6623089dd4ee8a323aecd644572adf0206cb1967aeffdbc
#   Stored in directory: /home/vscode/.cache/pip/wheels/e2/5c/da/74b1353d54468703298f99740b79686e9314fe7384e0f97f56
# Successfully built distance
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import distance

# %%
s1 = "Fabricio F. Santana"
s2 = "Fabricio F Santana"

distance.levenshtein(s1, s2)
# Out:
# 1

# %%
distance.nlevenshtein(s1, s2, method=1)
# Out:
# 0.05263157894736842

# %%
distance.jaccard(s1, s2)
# Out:
# 0.08333333333333337

# %%
distance.fast_comp(s1, s2)
# Out:
# 1
