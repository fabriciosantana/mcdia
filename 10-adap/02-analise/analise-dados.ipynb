# %% [markdown]
# 1. Importar pacotes

# %%
import pandas as pd
import requests

# %% [markdown]
# 2. Definir a URL

# %%
server_url = "https://dadosabertos.compras.gov.br//modulo-material/1_consultarGrupoMaterial"

# %% [markdown]
# 3. Fazer a requisição para obter os dados

# %%
response = requests.get(server_url)

if response.status_code == 200:
    resultado_grupo = response.json()

    print(resultado_grupo)
else:
    print("Erro: ", responde.txt)
# Out:
# {'resultado': [{'codigoGrupo': 10, 'nomeGrupo': 'ARMAMENTO', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 11, 'nomeGrupo': 'MATERIAIS BÉLICOS NUCLEARES', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 12, 'nomeGrupo': 'EQUIPAMENTOS DE TIRO', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 13, 'nomeGrupo': 'MUNIÇÕES E EXPLOSIVOS', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 14, 'nomeGrupo': 'MÍSSEIS GUIADOS', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 15, 'nomeGrupo': 'AERONAVES E SEUS COMPONENTES ESTRUTURAIS', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 16, 'nomeGrupo': 'COMPONENTES E ACESSORIOS DE AERONAVES', 'statusGrupo': True, 'dataHoraAtualizacao': '2021-10-16T09:16:33.723625'}, {'codigoGrupo': 17, 'nomeGrupo
# ...

# %% [markdown]
# 4. Recuperar o resultado e armazenar em uma variável

# %%
resultado = resultado_grupo["resultado"]

total_registros = resultado_grupo["totalRegistros"]

print(total_registros)
print(resultado)
# Out:
# 79
# ...

# %% [markdown]
# 5. Vamos colocar em um Data Frame

# %%
df_grupo = pd.DataFrame(resultado)

df_grupo
# Out:
#     codigoGrupo                                          nomeGrupo  \
# 0            10                                          ARMAMENTO
# 1            11                        MATERIAIS BÉLICOS NUCLEARES
# 2            12                               EQUIPAMENTOS DE TIRO
# 3            13                              MUNIÇÕES E EXPLOSIVOS
# 4            14                                    MÍSSEIS GUIADOS
# ..          ...                                                ...
# 74           94                      MATÉRIAS-PRIMAS NAO METÁLICAS
# 75           95              BARRAS, CHAPAS E PERFILADOS METÁLICOS
# 76           96       MINÉRIOS, MINERAIS E SEUS PRODUTOS PRIMÁRIOS
# 77           99                                           DIVERSOS
# 78           65  EQUIPAMENTOS E ARTIGOS PARA USO MÉDICO, DENTÁR...
#
#     statusGrupo         dataHoraAtualizacao
# 0          True  2021-10-16T09:16:33.723625
# 1          True  2021-10-16T09:16:33.723625
# ...

# %% [markdown]
# 6. Análise Macro do Data Frame

# %%
df_grupo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigoGrupo          79 non-null     int64
#  1   nomeGrupo            79 non-null     str
#  2   statusGrupo          79 non-null     bool
#  3   dataHoraAtualizacao  79 non-null     str
# dtypes: bool(1), int64(1), str(2)
# memory usage: 7.1 KB
