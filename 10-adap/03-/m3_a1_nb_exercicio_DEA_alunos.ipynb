# %% [markdown]
# # Exercício do Módulo III
# # Análise de desempenho - DEA (Data Envelope Analisys)
# # Comparação de Indicadores de Desenvolvimento Humano em Regiões
#
# Esse exemplo é baseado no trabalho "USO DE DEA COMO ALTERNATIVA AO IDH NA MENSURAÇÃO DO DESENVOLVIMENTO HUMANO NOS MAIORES MUNICÍPIOS BRASILEIROS" - Eliezer Panceri da Gama Bezerra - XXII Encontro Nacional de Engenharia de Produção
#
# Neste exercício, exploraremos os modelos DEA orientados a input. Os modelos orientados a input visam minimizar os inputs mantendo os outputs constantes, enquanto os modelos orientados a output (já vistos) buscam maximizar os outputs mantendo os inputs constantes.
#
# Siga os passos:
#
# ### 1. Ler o arquivo de dados dea_desenv_humano.csv
# Carregue o arquivo em um DataFrame do pandas.
# ### 2. Separar entradas e saídas
# Identifique e separe as colunas de input (X) e output (Y) para este novo dataset.
# ### 3. Executar o solver adequado, conforme solicitado no notebook
# Execute CCR_O ou CCR_I ou BCC_O ou BCC_I.
#
#
# ### 4. Apresentar os resultados (Eficiência Relativa)
# Exiba a eficiência relativa de cada DMUs.
#
#
# ## Importando o pacote DEA do Professor e outros pacotes

# %%
from google.colab import drive
drive.mount('/content/drive')
DATA_PATH = '/content/drive/MyDrive/Aulas/Aulas IDP/2026/Auditoria de Dados e Accountability/modulo III - Aud operacional/dea'
# Out:
# Mounted at /content/drive

# %%
# !git clone https://gitlab.com/aloisio/adndea.git
# Out:
# Cloning into 'adndea'...
# remote: Enumerating objects: 30, done.
# remote: Total 30 (delta 0), reused 0 (delta 0), pack-reused 30 (from 1)
# Receiving objects: 100% (30/30), 5.99 KiB | 5.99 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
import adndea.solver as dea
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## Lendo os dados de desenvolvimento humano

# %%
df_desenv = pd.read_csv(os.path.join(DATA_PATH, "dea_desenv_humano.csv"))
df_desenv
# Out:
#   dmu  Renda  ExpecVida  Conhecimento  Satisfacao
# 0   N  11436       56.7           2.0         7.5
# 1  A1   5122       48.6           1.4         8.0
# 2  A2   6714       45.8           1.8         7.0
# 3  A3    950       38.7           0.5         5.0
# 4  A4   2200       37.0           0.9         4.5
# 5  A5    500       35.0           0.8         3.5
# 6  A6   3000       48.5           1.2         6.5
# 7  A7   4200       52.0           1.7         6.0
# 8  A8   1780       50.6           1.0         3.0
# 9  A9   7000       59.0           1.5         9.0

# %% [markdown]
# ##### Dada a entrada renda, os resultados considerados são expectativa de vida, conecimento e satisfação.
#
# ##### Vamos encarar este problema como um problema orientado a outputs com retorno variável de escala. Queremos avaliar quem são as unidades ineficientes em relação à renda

# %% [markdown]
# ## Separando entradas e saídas

# %%
# Depare aqui

# %%
X

# %%
Y

# %% [markdown]
# ## Executando o solver dea BCC orientado a outpus

# %%
resp = dea # complete

# %% [markdown]
# ### Exibindo a resposta

# %%
resp

# %% [markdown]
# ## Atribuindo a eficiência ao dataframe principal

# %%
df_desenv["ef_relativa"] = # complete
df_desenv

# %% [markdown]
# ## Exibindo apenas as unidades ineficientes

# %%
display(  df_desenv[  df_desenv.ef_relativa < 1    ] )
