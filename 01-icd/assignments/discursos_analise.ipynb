# %%
# importação de bibliotecas
import requests
import pandas as pd
import matplotlib.pyplot as plt

# Configuração de estilo dos gráficos
plt.style.use("seaborn-v0_8")

base_url = "https://legis.senado.gov.br/dadosabertos/"

# %% [markdown]
# ## Parlamentares da 56ª Legislatura (2019 a 2023)

# %%
legislatura = 56
url_senadores_legislatura = base_url + f"senador/lista/legislatura/{legislatura}.csv"
csv_senadores_legistura = f"_data/senador_lista_legistatura_{legislatura}.csv"

params = {    
            #"uf": "RJ",
            #"participacao": "T",
            #"exercicio": "exercicio",
            "v": 4
        }

headers = {"Accept": "txt/csv"}

with requests.get(url_senadores_legislatura, params=params, headers=headers, stream=True, timeout=60) as r:
    r.raise_for_status()
    with open(csv_senadores_legistura, "wb") as f:
        for chunk in r.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)

dataframe_senadores_lista_legislatura = pd.read_csv(csv_senadores_legistura, sep=";")

print(f"Arquivo com Senadores da Legislatura {legislatura} salvo com sucesso!")
dataframe_senadores_lista_legislatura.head()
# Out:
# Arquivo com Senadores da Legislatura 56 salvo com sucesso!
#    /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/CodigoParlamentar  \
# 0                                               5573
# 1                                               4981
# 2                                               4981
# 3                                               4981
# 4                                               4981
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/NomeParlamentar  \
# 0                                      Abel Rebouças
# 1                                       Acir Gurgacz
# 2                                       Acir Gurgacz
# 3                                       Acir Gurgacz
# 4                                       Acir Gurgacz
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/NomeCompletoParlamentar  \
# 0                             Abel Rebouças São José
# 1                                Acir Marcos Gurgacz
# 2                                Acir Marcos Gurgacz
# 3                                Acir Marcos Gurgacz
# 4                                Acir Marcos Gurgacz
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/SexoParlamentar  \
# 0                                          Masculino
# 1                                          Masculino
# 2                                          Masculino
# 3                                          Masculino
# 4                                          Masculino
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/FormaTratamento  \
# 0                                           Senador
# 1                                           Senador
# 2                                           Senador
# 3                                           Senador
# 4                                           Senador
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/SiglaPartidoParlamentar  \
# 0                                                PDT
# 1                                                PDT
# 2                                                PDT
# 3                                                PDT
# 4                                                PDT
#
#    /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/CodigoMandato  \
# 0                                              492.0
# 1                                              515.0
# 2                                              515.0
# 3                                              515.0
# 4                                              515.0
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/UfParlamentar  \
# 0                                                 BA
# 1                                                 RO
# 2                                                 RO
# 3                                                 RO
# 4                                                 RO
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/DescricaoParticipacao  \
# 0                                        1º Suplente
# 1                                            Titular
# 2                                            Titular
# 3                                            Titular
# 4                                            Titular
#
#    /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/PrimeiraLegislaturaDoMandato/NumeroLegislatura  \
# 0                                               55.0
# 1                                               55.0
# 2                                               55.0
# 3                                               55.0
# 4                                               55.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/UrlPaginaParlamentar  \
# 0                                                NaN
# 1  http://www25.senado.leg.br/web/senadores/senad...
# 2  http://www25.senado.leg.br/web/senadores/senad...
# 3  http://www25.senado.leg.br/web/senadores/senad...
# 4  http://www25.senado.leg.br/web/senadores/senad...
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/UrlPaginaParticular  \
# 0                                                NaN
# 1                        https://acirgurgacz.com.br/
# 2                        https://acirgurgacz.com.br/
# 3                        https://acirgurgacz.com.br/
# 4                        https://acirgurgacz.com.br/
#
#    /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/EmailParlamentar  \
# 0                                                NaN
# 1                      sen.acirgurgacz@senado.leg.br
# 2                      sen.acirgurgacz@senado.leg.br
# 3                      sen.acirgurgacz@senado.leg.br
# 4                      sen.acirgurgacz@senado.leg.br
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/CodigoExercicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             2810.0
# 4                                             2754.0
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/DataInicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         2017-01-14
# 4                                         2015-02-01
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/DataFim  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         2023-01-31
# 4                                         2016-09-08
#
#    /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/SiglaCausaAfastamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                TER
# 4                                                LSP
#
#   /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/DescricaoCausaAfastamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                 Término do mandato
# 4                           Licença Saúde-Particular
#
#   /Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/UfParlamentar  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    /Servico/Parlamentares/Parlamentar/Mandatos/Mandato/Exercicios/Exercicio/DataLeitura
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Parlamentares da 56ª Legislatura por forma de tratamento

# %%
col = "IdentificacaoParlamentar.SexoParlamentar"
parlamentares[col] = parlamentares[col].astype(str).str.strip()

contagem = (
    parlamentares
      .groupby(col, dropna=True)
      .size()
      .reset_index(name="quantidade")
      .sort_values("quantidade", ascending=False)
)

contagem.head(3)
# Out:
#   IdentificacaoParlamentar.SexoParlamentar  quantidade
# 1                                Masculino         197
# 0                                 Feminino          48

# %% [markdown]
# ### Detalhes de um Parlamentar

# %%
codigos_parlamentares = dataframe_senadores_lista_legislatura["/Servico/Parlamentares/Parlamentar/IdentificacaoParlamentar/CodigoParlamentar"]

#codigos_parlamentares

urls_detalhe_senador = [base_url + f"senador/{codigo_parlamentar}.csv" for codigo_parlamentar in codigos_parlamentares]
urls_detalhe_senador[0]
csv_detalhes_senador = [f"_data/senador_{codigo_parlamentar}.csv" for codigo_parlamentar in codigos_parlamentares]
csv_detalhes_senador[0]


requests.get(urls_detalhe_senador[0], params, headers=headers, stream=True, timeout=60)

for i in range(len(urls_detalhe_senador)):
    with requests.get(urls_detalhe_senador[i], headers=headers, stream=True, timeout=60) as r:
        r.raise_for_status()
        with open(csv_detalhes_senador[i], "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
    print(f"Detalhes do Senador {urls_detalhe_senador[i]} gravado com sucesso em {csv_detalhes_senador[i]}")

#response = requests.get(url[0], headers=headers)

#detalhe_parlamentar = response.json()
#detalhe_parlamentar = detalhe_parlamentar["DetalheParlamentar"]["Parlamentar"]["IdentificacaoParlamentar"]
#detalhe_parlamentar = pd.json_normalize(detalhe_parlamentar, sep=".")

#detalhes_parlamentares
#detalhe_parlamentares = detalhe_parlamentar


#detalhe_parlamentares.append(detalhe_parlamentar)

#detalhe_parlamentares
# Out:
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5573.csv gravado com sucesso em _data/senador_5573.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/4981.csv gravado com sucesso em _data/senador_4981.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/
csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5718.csv gravado com sucesso em _data/senador_5718.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5718.csv gravado com sucesso em _data/senador_5718.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5718.csv gravado com sucesso em _data/senador_5718.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5718.csv gravado com sucesso em _data/senador_5718.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5531.csv gravado com sucesso em _data/senador_5531.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5531.csv gravado com sucesso em _data/senador_5531.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5531.csv gravado com sucesso em _data/senador_5531.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5531.csv gravado com sucesso em _data/senador_5531.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5531.csv gravado com sucesso em _data/senador_5531.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/6025.csv gravado com sucesso em _data/senador_6025.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/22.csv gravado com sucesso em _data/senador_22.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/22.csv gravado com sucesso em _data/senador_22.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/22.csv gravado com sucesso em _data/senador_22.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5953.csv gravado com sucesso em _data/senador_5953.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5953.csv gravado com sucesso em _data/senador_5953.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5953.csv gravado com sucesso em _data/senador_5953.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5740.csv gravado com sucesso em _data/senador_5740.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5581.csv gravado com sucesso em _data/senador_5581.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5540.csv gravado com sucesso em _data/senador_5540.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5540.csv gravado com sucesso em _data/senador_5540.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5540.csv gravado com sucesso em _data/senador_5540.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/5980.csv gravado com sucesso em _data/senador_5980.csv
# Detalhes do Senador https://legis.senado.gov.br/dadosabertos/senador/4525.csv gravado com sucesso em _data/senador_4525.csv

# %% [markdown]
# ## Entes

# %%
url = base_url + "processo/entes"

params = { "participação" : "T" }

response = requests.get(url, params)

# Verificando resposta
if (response.status_code == 200):
    entes = pd.DataFrame(response.json())
    entes = entes[pd.isnull(entes["dataFim"])]
else:
    print("Tratar retorno diferente de 200")

entes
# Out:
#             id sigla                                               nome  casa  \
# 0      7378493  None  1ª Câmara de Coordenação e Revisão -Direitos S...  None
# 1      7378350  None  1ª Câmara de Coordenação e Revisão do Ministér...  None
# 2          301  None  1º Vice-Presidente da Mesa do Congresso Nacion...  None
# 3      7376109  None  2ª Vara Cível, Família e Sucessões Inf. e Juve...  None
# 4      7376147  None  2ª Vara de Família, Sucessões, Órfãos, Interdi...  None
# ...        ...   ...                                                ...   ...
# 11374  7380144  None         associação brasileira de reciclagem animal  None
# 11375  7349474  None                                            e-PETRO  None
# 11376  7349700  None                                              emgea  None
# 11377  7377116  None  entidades representativas do setor vitivinícol...  None
# 11379  7371615  None                        tribunal de contas da união  None
#
#            siglaTipo                     descricaoTipo dataInicio dataFim
# 0      ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 1      ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 2      ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 3      ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 4      ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# ...              ...                               ...        ...     ...
# 11374  ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 11375  ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 11376  ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 11377  ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
# 11379  ENTE_JURIDICO  Ente Jurídico - não categorizado       None    None
#
# [10397 rows x 8 columns]

# %%
url = base_url + "processo"

params = {
            #"numero": "",
            #"ano": "2025",
            #"idProcesso": "",
            #"codigoMateria": "",
            "tramitando": "S",
            #tramitouLegislaturaAtual": "S" 
            "sigla": "SUG",
            #"dataInicioApresentacao": "2024-01-01",
            #"dataFimApresentacao": "2024-12-31",
            

        }

response = requests.get(url, params=params)

if (response.status_code == 200):
    processos = pd.DataFrame(response.json())
else:
    print(f"Tratar retorno {response.status_code}")

processos
# Out:
#          id  codigoMateria identificacao casaIdentificadora enteIdentificador  \
# 0   7388637         133210   SUG 12/2018                 SF               CDH
# 1   7394544         133422   SUG 13/2018                 SF               CDH
# 2   7706254         134957   SUG 39/2018                 SF              PLEN
# 3   7727050         135618    SUG 2/2019                 SF               CDH
# 4   7727055         135619    SUG 3/2019                 SF               CDH
# ..      ...            ...           ...                ...               ...
# 95  8856603         169354    SUG 7/2025                 SF               CDH
# 96  8860593         169458    SUG 8/2025                 SF               CDH
# 97  8890480         170012    SUG 9/2025                 SF               CDH
# 98  8890490         170013   SUG 10/2025                 SF               CDH
# 99  8891866         170030   SUG 11/2025                 SF               CDH
#
#             tipoConteudo                                             ementa  \
# 0   Sugestão Legislativa  Institui o Estatuto do Trabalho e regulamenta ...
# 1   Sugestão Legislativa            Revoga as Leis 13.467/2017 e 13429/2017
# 2   Sugestão Legislativa  Institui no ambiente escolar a Semana Nacional...
# 3   Sugestão Legislativa  Isenção do IRPF para Profissionais de Seguranç...
# 4   Sugestão Legislativa  Enfermeiros(as)com piso salarial de R$ 4.800,0...
# ..                   ...                                                ...
# 95  Sugestão Legislativa  Dispõe sobre criação de "Lei Federal para a pr...
# 96  Sugestão Legislativa  Dispõe sobre "Piso salarial e carga horária de...
# 97  Sugestão Legislativa  Proíbe o abate do jumento (Equus asinus) em to...
# 98  Sugestão Legislativa         Dispõe sobre: "Estatuto dos Cães e Gatos".
# 99  Sugestão Legislativa  Estabelece a manutenção do Auxílio Alimentação...
#
#    tipoDocumento dataApresentacao  \
# 0       Sugestão       2018-05-10
# 1       Sugestão       2018-05-28
# 2       Sugestão       2018-12-18
# 3       Sugestão       2019-02-14
# 4       Sugestão       2019-02-14
# ..           ...              ...
# 95      Sugestão       2025-06-30
# 96      Sugestão       2025-07-08
# 97      Sugestão       2025-08-22
# 98      Sugestão       2025-08-22
# 99      Sugestão       2025-08-26
#
#                                               autoria tramitando  \
# 0                        ALJT, Anamatra, ANPT, Sinait        Sim
# 1        NCST, CONTRATUH, CNTI, CSPB, CNTTT e  CNTEEC        Sim
# 2   Jovem Senador Jovem Senadora Ana Beatriz Barro...        Sim
# 3                                Programa e-Cidadania        Sim
# 4                                Programa e-Cidadania        Sim
# ..                                                ...        ...
# 95                               Programa e-Cidadania        Sim
# 96                               Programa e-Cidadania        Sim
# 97         FORUM NACIONAL DE PROTECAO E DEFESA ANIMAL        Sim
# 98  Instituto Arcanimal; Instituto Faço pelos Anim...        Sim
# 99                               Programa e-Cidadania        Sim
#
#    ultimaInformacaoAtualizada    dataUltimaAtualizacao  \
# 0          EVENTO_LEGISLATIVO  2025-08-14T13:54:32.061
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3          EVENTO_LEGISLATIVO  2025-05-08T17:36:02.076
# 4          EVENTO_LEGISLATIVO  2025-04-25T17:25:24.123
# ..                        ...                      ...
# 95         EVENTO_LEGISLATIVO  2025-08-14T14:46:48.846
# 96         EVENTO_LEGISLATIVO   2025-08-27T10:46:15.56
# 97         EVENTO_LEGISLATIVO  2025-09-09T16:13:53.598
# 98         EVENTO_LEGISLATIVO   2025-08-25T18:09:04.37
# 99         EVENTO_LEGISLATIVO  2025-09-09T16:16:06.005
#
#                                          urlDocumento
# 0   https://legis.senado.gov.br/sdleg-getter/docum...
# 1   https://legis.senado.gov.br/sdleg-getter/docum...
# 2   https://legis.senado.gov.br/sdleg-getter/docum...
# 3   https://legis.senado.gov.br/sdleg-getter/docum...
# 4   https://legis.senado.gov.br/sdleg-getter/docum...
# ..                                                ...
# 95  https://legis.senado.gov.br/sdleg-getter/docum...
# 96  https://legis.senado.gov.br/sdleg-getter/docum...
# 97  https://legis.senado.gov.br/sdleg-getter/docum...
# 98  https://legis.senado.gov.br/sdleg-getter/docum...
# 99  https://legis.senado.gov.br/sdleg-getter/docum...
#
# [100 rows x 14 columns]

# %%
# ================================
# 3. Transformação em DataFrame
# ================================
# A API retorna XML/JSON dependendo da rota; 
# aqui usamos JSON (quando disponível) ou convertemos.

# Obs.: para XML seria preciso usar xml.etree.ElementTree ou lxml

data = response.json()
materias = data['ListaMaterias']['Materias']['Materia']

# Criando DataFrame
df = pd.DataFrame(materias)

# Exibir primeiras linhas
df.head()

# %%
# ================================
# 4. Limpeza e preparação
# ================================
# Selecionando variáveis de interesse
colunas = ["idMateria", "siglaCasa", "siglaTipo", "numero", "ano", "ementa", "descricaoSituacao"]
df = df[colunas]

# Ajustar tipos de dados
df["ano"] = df["ano"].astype(int)
df["numero"] = df["numero"].astype(int)

df.head()

# %%
# ================================
# 5. Estatísticas descritivas
# ================================
print("Total de proposições:", len(df))
print("\nResumo estatístico:")
print(df.describe(include="all"))

# %%
# ================================
# 6. Visualizações iniciais
# ================================

# Quantidade de proposições por tipo
df["siglaTipo"].value_counts().plot(kind="bar", figsize=(8,4))
plt.title("Distribuição por Tipo de Proposição")
plt.xlabel("Tipo")
plt.ylabel("Quantidade")
plt.show()

# Proposições por ano
df["ano"].value_counts().sort_index().plot(kind="line", marker="o", figsize=(8,4))
plt.title("Proposições por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.show()

# %%
# ================================
# 7. Discussão preliminar (anotações)
# ================================
# - Identificar variáveis com dados ausentes.
print(df.isna().sum())

# - Refletir sobre possíveis problemas:
#   * Situações pouco padronizadas.
#   * Textos longos em 'ementa' -> análise qualitativa ou NLP.
#   * Discrepâncias entre anos com muitas/ poucas proposições.

# %%
df = pd.read_csv("_data/discursos_2019-01-01_2023-01-31.csv", sep=";")
df.head()
# Out:
#        id  CodigoPronunciamento            Casa        Data  \
# 0  451286                451286  Senado Federal  2019-02-27
# 1  451285                451285  Senado Federal  2019-02-27
# 2  451205                451205  Senado Federal  2019-02-27
# 3  451203                451203  Senado Federal  2019-02-27
# 4  451202                451202  Senado Federal  2019-02-27
#
#                                               Resumo  \
# 0  Comentários a respeito da concentração bancári...
# 1  Registro do impacto da reforma da previdência ...
# 2  Comentários a respeito da catástrofe ocorrida ...
# 3  Expectativa com o início dos trabalhos no âmbi...
# 4  Relato da origem e das motivações do Projeto d...
#
#                                            Indexacao  \
# 0  COMENTARIO, CONCENTRAÇÃO, REDE BANCARIA, COBRA...
# 1  REGISTRO, REFORMA, PREVIDENCIA SOCIAL, ALTERAÇ...
# 2  COMENTARIO, DESASTRE, ROMPIMENTO, BARRAGEM, BR...
# 3  EXPECTATIVA, INICIO, TRABALHO, COMISSÕES, SENA...
# 4  COMENTARIO, ORIGEM, MOTIVO, PROJETO DE LEI, OB...
#
#                                        TextoIntegral  \
# 0  https://www25.senado.leg.br/web/atividade/pron...
# 1  https://www25.senado.leg.br/web/atividade/pron...
# 2  https://www25.senado.leg.br/web/atividade/pron...
# 3  https://www25.senado.leg.br/web/atividade/pron...
# 4  https://www25.senado.leg.br/web/atividade/pron...
#
#                                     TextoIntegralTxt  \
# 0  https://legis.senado.leg.br/dadosabertos/discu...
# 1  https://legis.senado.leg.br/dadosabertos/discu...
# 2  https://legis.senado.leg.br/dadosabertos/discu...
# 3  https://legis.senado.leg.br/dadosabertos/discu...
# 4  https://legis.senado.leg.br/dadosabertos/discu...
#
#                                      UrlTextoBinario   TipoAutor  ...  \
# 0  https://legis.senado.leg.br/dadosabertos/discu...  Senador(a)  ...
# 1  https://legis.senado.leg.br/dadosabertos/discu...  Senador(a)  ...
# 2  https://legis.senado.leg.br/dadosabertos/discu...  Senador(a)  ...
# 3  https://legis.senado.leg.br/dadosabertos/discu...  Senador(a)  ...
# 4  https://legis.senado.leg.br/dadosabertos/discu...  Senador(a)  ...
#
#   TipoUsoPalavra.Sigla TipoUsoPalavra.Descricao  \
# 0                  DIS                 Discurso
# 1                  DIS                 Discurso
# 2                  DIS                 Discurso
# 3                  DIS                 Discurso
# 4                  DIS                 Discurso
#
#    TipoUsoPalavra.IndicadorAtivo  \
# 0                            Sim
# 1                            Sim
# 2                            Sim
# 3                            Sim
# 4                            Sim
#
#                               Publicacoes.Publicacao Apartes.Aparteante  \
# 0  [{'TipoPublicacao': 'PUB', 'DataPublicacao': '...                NaN
# 1  [{'TipoPublicacao': 'PUB', 'DataPublicacao': '...                NaN
# 2  [{'TipoPublicacao': 'PUB', 'DataPublicacao': '...                NaN
# 3  [{'TipoPublicacao': 'PUB', 'DataPublicacao': '...                NaN
# 4  [{'TipoPublicacao': 'PUB', 'DataPublicacao': '...                NaN
#
#    __janela_inicio __janela_fim CargoAutor OrgaoAutor PaisAutor
# 0       2019-02-01   2019-03-03        NaN        NaN       NaN
# 1       2019-02-01   2019-03-03        NaN        NaN       NaN
# 2       2019-02-01   2019-03-03        NaN        NaN       NaN
# 3       2019-02-01   2019-03-03        NaN        NaN       NaN
# 4       2019-02-01   2019-03-03        NaN        NaN       NaN
#
# [5 rows x 26 columns]
