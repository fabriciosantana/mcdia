# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriciosantana/mcdia/blob/main/01-icd/assignments/01_preparar_base_discursos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparar base de dados com discursos dos senadores
#
# Ao final deste notebook é esperado que se tenha uma base de dados (arquivo parquet) no diretório _data. Para evitar fazer download de novos dados, é dado a opção de reaproveitar arquivo baixando anteriormente para o mesmo período de data

# %% [markdown]
# ## Instalar dependências
#
# Instale as dependências necessárias.

# %%
# %pip install requests pandas pyarrow

# %% [markdown]
# ## Importar bibliotecas

# %%
import time
import datetime as dt
import logging
import requests
import pandas as pd
import re
from pathlib import Path
from typing import List, Dict, Any
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from pprint import pformat

# %% [markdown]
# ## Inicializar variáveis globais

# %%
BASE = "https://legis.senado.leg.br/dadosabertos/"

TIMEOUT_JSON = 90
TIMEOUT_TXT  = 60
RETRY_TOTAL  = 8
RETRY_BACKOFF = 0.6
STATUS_FORCELIST = [429, 500, 502, 503, 504]

DEFAULT_INI = dt.date(2019, 3, 29)
DEFAULT_FIM = dt.date(2019, 3, 31)

DATA_DIR = Path("_data")
DATA_DIR.mkdir(exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)
log = logging.getLogger("discursos")

# %% [markdown]
# ## Definir métodos utilitários
#
# Execute as céluas abaixo para definir métodos que serão utilizados na preparação da base de dados

# %% [markdown]
# ### Criar sessão HTTP
#
# Os dados são obtidos do portal de dados abertos do Senado por meio de requisições HTTP

# %%
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=RETRY_TOTAL,
        backoff_factor=RETRY_BACKOFF,
        status_forcelist=STATUS_FORCELIST,
        allowed_methods=["GET"],
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))

    log.info(f">>> Headers: {pformat(dict(s.headers))}")
    log.info(f">>> Cookies: {s.cookies}")
    log.info(f">>> Auth: {s.auth}")

    return s

log.info(f"Construindo sessão HTTP")
sess = make_session()
# Out:
# 2025-09-25 18:52:42,801 [INFO] Construindo sessão HTTP
# 2025-09-25 18:52:42,804 [INFO] >>> Headers: {'Accept': '*/*',
#  'Accept-Encoding': 'gzip, deflate',
#  'Connection': 'keep-alive',
#  'User-Agent': 'python-requests/2.32.4'}
# 2025-09-25 18:52:42,805 [INFO] >>> Cookies: <RequestsCookieJar[]>
# 2025-09-25 18:52:42,805 [INFO] >>> Auth: None

# %% [markdown]
# ### Montar intervalo de datas
#
# As requisições à API do Senado só pode ser realizada para intervalos de 31 dias. A partir de um intervalo de datas, o método abaixo criar intervalos no período pré-definido.

# %%
def montar_intervalo_de_datas(start: dt.date, end: dt.date, days_per_window: int = 31) -> List[tuple]:
    """Gera janelas [ini, fim] inclusive, com no máx. 'days_per_window' dias cada."""

    log.info(f">>> Montando intervalos de {days_per_window} dias para fazer download dos discursos em blocos")

    windows = []
    cur = start
    one_day = dt.timedelta(days=1)

    while cur <= end:
        w_end = min(cur + dt.timedelta(days=days_per_window - 1), end)
        windows.append((cur, w_end))
        log.info(f">>> >>> Janela {len(windows)}: {(cur, w_end)}")
        cur = w_end + one_day

    log.info(f">>> O download dos discursos será realizado em {len(windows)} intervalos")
    return windows

# %% [markdown]
# ### Extrair discurso

# %%
def extrair_discurso(obj: Any) -> List[Dict[str, Any]]:
    """
    Procura, recursivamente, qualquer lista sob a chave 'Pronunciamento'.
    Isso torna o parser resiliente a pequenas mudanças de envelope.
    """
    out = []

    def rec(x):
        if isinstance(x, dict):
            for k, v in x.items():
                if isinstance(k, str) and k.lower() == "pronunciamento" and isinstance(v, list):
                    out.extend(v)
                else:
                    rec(v)
        elif isinstance(x, list):
            for it in x:
                rec(it)

    rec(obj)
    return out

# %% [markdown]
# ### Recuperar discurso de um período

# %%
def recuperar_lista_discursos_por_periodo(data_inicio: dt.date, data_fim: dt.date, sleep_s: float = 0.0) -> pd.DataFrame:
    """
    Busca discursos do Plenário por janelas de data, agregando tudo num DataFrame.
    Endpoint: /plenario/lista/discursos/{AAAAMMDD}/{AAAAMMDD}.json
    """

    log.info(f">>> Preparando intervalos para download dos discursos de {data_inicio} a {data_fim}")
    windows = montar_intervalo_de_datas(data_inicio, data_fim, days_per_window=31)  # janelas de ~1 mês

    log.info(f">>> Iniciando download dos discursos em {len(windows)} intervalos")
    all_rows = []

    for i, (data_ini, data_fim) in enumerate(windows, 1):
        url = f"{BASE}plenario/lista/discursos/{data_ini.strftime('%Y%m%d')}/{data_fim.strftime('%Y%m%d')}.json"

        log.info(f">>> >>> GET: {url}")
        r = sess.get(url, headers={"Accept": "application/json"}, timeout=TIMEOUT_JSON)
        r.raise_for_status()
        j = r.json()

        log.info(f">>> >>> Extraindo discurso")
        pron = extrair_discurso(j)
        if pron:
            # flatten resiliente
            df = pd.json_normalize(pron, sep=".")
            # anexa janela de coleta (útil para auditoria)
            df["__janela_inicio"] = data_ini.isoformat()
            df["__janela_fim"] = data_fim.isoformat()
            all_rows.append(df)
            log.info(f">>> >>> Discursos extraídos: {len(all_rows)}")

        if sleep_s:
            time.sleep(sleep_s)

    if not all_rows:
        return pd.DataFrame()

    df_all = pd.concat(all_rows, ignore_index=True, sort=False)
    log.info(f">>> Discursos recuperados: {len(df_all)}")

    return df_all

# %% [markdown]
# ### Recuperar texto integral de um discurso

# %%
def recuperar_texto_discurso(codigo_pron: str, url_txt: str) -> dict:
    out = {"CodigoPronunciamento": codigo_pron, "TextoDiscursoIntegral": "", "ok": False, "status": None, "msg": ""}

    try:
        log.info(f">>> GET: {url_txt}")
        r = sess.get(url_txt, timeout=TIMEOUT_TXT, headers={"Accept": "text/plain, */*;q=0.1"}, allow_redirects=True)
        out["status"] = r.status_code

        # log auxiliar para diagnosticar
        ct = (r.headers.get("Content-Type") or "").lower()
        if r.status_code == 404:
            out["msg"] = "404 (sem texto integral)";  return out
        if r.status_code == 204:
            out["msg"] = "204 (sem conteúdo)";        return out

        r.raise_for_status()

        # conteúdo
        txt = r.text or ""
        # limpeza leve (uso de re.sub, não r.sub)
        txt = re.sub(r"\s+\n", "\n", txt)
        txt = re.sub(r"[ \t]+", " ", txt).strip()

        # proteção: se veio vazio, registra e sai
        if not txt:
            out["msg"] = f"vazio (Content-Type={ct})"
            return out

        out["ok"] = True
        out["TextoDiscursoIntegral"] = txt
        return out

    except Exception as e:
        out["msg"] = str(e)
        return out

# %% [markdown]
# ### Preparar discurso para download

# %%
def preparar_discursos_para_download(
    df_discursos: pd.DataFrame,
    cols_necessarias=("TextoIntegralTxt", "CodigoPronunciamento"),
    inplace: bool = False
) -> pd.DataFrame:
    """
    - Faz rename tolerante das colunas necessárias para os nomes canônicos em `cols_necessarias`.
    - Converte para string e strip.
    - Retorna APENAS as linhas com URL válida em `TextoIntegralTxt` (http/https).
    """
    df = df_discursos if inplace else df_discursos.copy()

    # 1) garantir/renomear colunas
    ren = {}
    for alvo in cols_necessarias:
        col_real = _match_col(df, alvo)
        if col_real != alvo:
            ren[col_real] = alvo
    if ren:
        df = df.rename(columns=ren)

    # 2) normalizar valores
    for alvo in cols_necessarias:
        df[alvo] = df[alvo].astype(str).str.strip()

    # 3) filtrar URLs válidas
    df_filtrado = df[df["TextoIntegralTxt"].str.startswith(("http://", "https://"), na=False)].copy()

    return df_filtrado

def _match_col(df: pd.DataFrame, alvo: str) -> str:
    """
    Tenta encontrar em df.columns a coluna equivalente a `alvo`.
    Estratégia: match exato (case-insensitive) -> contém (case-insensitive).
    Retorna o nome da coluna encontrada ou levanta KeyError.
    """
    cols = list(df.columns)
    # 1) exato (case-insensitive)
    for c in cols:
        if c.lower() == alvo.lower():
            return c
    # 2) contém (case-insensitive)
    candidatos = [c for c in cols if alvo.lower() in c.lower()]
    if candidatos:
        # prioriza o mais curto (geralmente o nome mais "limpo")
        return sorted(candidatos, key=len)[0]
    raise KeyError(f"Coluna obrigatória não encontrada: {alvo}. Disponíveis: {cols}")

# %% [markdown]
# ### Fazer download texto discurso

# %%
def fazer_download_texto_discursos(
    df_download,
    fetch_fn,                 # ex.: fetch_and_save_txt(codigo_pron, url_txt)
    max_workers: int = 8
):
    """
    Executa fetch_fn(CodigoPronunciamento, TextoIntegralTxt) em paralelo
    para cada linha de df_download e retorna a lista 'resultados'.

    - fetch_fn deve retornar um dict (ex.: {"CodigoPronunciamento":..., "ok":..., ...})
    """
    resultados = []
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        futs = {
            ex.submit(fetch_fn, row["CodigoPronunciamento"], row["TextoIntegralTxt"]): row
            for _, row in df_download.iterrows()
        }
        for fut in as_completed(futs):
            row = futs[fut]
            try:
                resultados.append(fut.result())
            except Exception as e:
                resultados.append({
                    "CodigoPronunciamento": row.get("CodigoPronunciamento"),
                    "ok": False,
                    "msg": str(e),
                })
    return pd.DataFrame(resultados)

# %% [markdown]
# ### Solicitar intervalo de datas

# %%
def ler_intervalo_datas() -> tuple[dt.date, dt.date]:
    print("Informe o intervalo (ENTER para usar padrão 2019-03-29 → 2019-03-31).")
    s_ini = input("Data inicial [2019-03-29]: ").strip()
    s_fim = input("Data final   [2019-03-31]: ").strip()

    ini = _parse_data(s_ini) if s_ini else DEFAULT_INI
    fim = _parse_data(s_fim) if s_fim else DEFAULT_FIM
    if fim < ini:
        ini, fim = fim, ini
        print(f"Aviso: datas invertidas. Usando {ini} → {fim}.")
    return ini, fim

def _parse_data(s: str) -> dt.date:
    s = (s or "").strip()
    for fmt in ("%Y-%m-%d", "%d/%m/%Y"):
        try:
            return dt.datetime.strptime(s, fmt).date()
        except ValueError:
            pass
    raise ValueError(f"Data inválida: {s!r}")

# %% [markdown]
# ### Perguntar de deseja utilizar arquivo baixado anteriormente

# %%
def ask_yes_no(msg: str, default_yes=True) -> bool:
    prompt = " [S/n] " if default_yes else " [s/N] "
    while True:
        ans = input(msg + prompt).strip().lower()
        if not ans:
            return default_yes
        if ans in ("s","sim","y","yes"): return True
        if ans in ("n","nao","não","no"): return False
        print("Responda com s/n.")

# %% [markdown]
# ## Fluxo principal para preparação da base

# %%
ini, fim = ler_intervalo_datas()

out_path = DATA_DIR / f"discursos_{ini.isoformat()}_{fim.isoformat()}.parquet"
#out_path = DATA_DIR / f"discursos_{ini.isoformat()}_{fim.isoformat()}.csv"

if out_path.exists():
    if ask_yes_no(f"Arquivo já existe: {out_path}\nUsar o arquivo existente?"):
        log.info(f"Usando: {out_path}")
        df_final = pd.read_parquet(out_path)
        #df_final = pd.read_csv(out_path, sep=";", dtype=str)
        log.info(f"Discursos existentes no arquivo: {len(df_final)}")
        log.info(f"OK: {df_final['ok'].eq(True).sum()} textos baixados, {len(df_final)-df_final['ok'].eq(True).sum()} sem texto. Arquivo salvo em: {out_path}")
        #log.info(df_final["TextoDiscursoIntegral"].str.len())
        raise SystemExit(0)
    else:
        log.info("Refazendo download dos discursos…")

log.info(f"Recuperando lista de discursos realizados no período de {ini} a {fim}")
df_discursos = recuperar_lista_discursos_por_periodo(ini, fim, sleep_s=0.0)
log.info(f"Lista de discursos recuperados: {len(df_discursos)}")

log.info(f"Prepando discursos para download")
df_download = preparar_discursos_para_download(df_discursos)
log.info(f"Discursos com link para download do texto integral {len(df_download)}")

log.info(f"Iniciando download do texto integral do discurso com link para texto integral: {len(df_download)}")
df_txt = fazer_download_texto_discursos(df_download, recuperar_texto_discurso, max_workers=8)
log.info(f"Foi realizado o download dos textos de discursos: {len(df_txt)}")

df_final = df_discursos.merge(
    df_txt[["CodigoPronunciamento", "TextoDiscursoIntegral", "ok", "status", "msg"]],
    on="CodigoPronunciamento",
    how="left"
)

log.info(f"Textos no data frame final: {len(df_final)}")
log.info(f"Discursos por período: {len(df_discursos):,} linhas")

log.info(f"Salvando arquivo com a lista dos discursos e os respectivos textos integrais")
df_final.to_parquet(out_path, index=False, engine="pyarrow", compression="zstd")
#df_final.to_csv(
#    out_path,
#    index=False,
#    sep=";")
log.info(f"OK: {df_final['ok'].eq(True).sum()} textos baixados, {len(df_final)-df_final['ok'].eq(True).sum()} sem texto. Arquivo salvo em: {out_path}")

#log.info(df_final["TextoDiscursoIntegral"].str.len())
#log.info(df_final["TextoDiscursoIntegral"].str.split().str.len())
# Out:
# Informe o intervalo (ENTER para usar padrão 2019-03-29 → 2019-03-31).
# 2025-09-25 18:53:26,543 [INFO] Recuperando lista de discursos realizados no período de 2019-02-01 a 2023-01-31
# 2025-09-25 18:53:26,544 [INFO] >>> Preparando intervalos para download dos discursos de 2019-02-01 a 2023-01-31
# 2025-09-25 18:53:26,545 [INFO] >>> Montando intervalos de 31 dias para fazer download dos discursos em blocos
# 2025-09-25 18:53:26,545 [INFO] >>> >>> Janela 1: (datetime.date(2019, 2, 1), datetime.date(2019, 3, 3))
# 2025-09-25 18:53:26,546 [INFO] >>> >>> Janela 2: (datetime.date(2019, 3, 4), datetime.date(2019, 4, 3))
# 2025-09-25 18:53:26,546 [INFO] >>> >>> Janela 3: (datetime.date(2019, 4, 4), datetime.date(2019, 5, 4))
# 2025-09-25 18:53:26,547 [INFO] >>> >>> Janela 4: (datetime.date(2019, 5, 5), datetime.date(2019, 6, 4))
# 2025-09-25 18:53:26,547 [INFO] >>> >>> Janela 5: (datetime.date(2019, 6, 5), datetime.date(2019, 7, 5))
# 2025-09-25 18:53:26,549 [INFO] >>> >>> Janela 6: (datetime.date(2019, 7, 6), datetime.date(2019, 8, 5))
# 2025-09-25 18:53:26,549 [INFO] >>> >>> Janela 7: (datetime.date(2019, 8, 6), datetime.date(2019, 9, 5))
# 2025-09-25 18:53:26,550 [INFO] >>> >>> Janela 8: (datetime.date(2019, 9, 6), datetime.date(2019, 10, 6))
# 2025-09-25 18:53:26,550 [INFO] >>> >>> Janela 9: (datetime.date(2019, 10, 7), datetime.date(2019, 11, 6))
# 2025-09-25 18:53:26,551 [INFO] >>> >>> Janela 10: (datetime.date(2019, 11, 7), datetime.date(2019, 12, 7))
# 2025-09-25 18:53:26,551 [INFO] >>> >>> Janela 11: (datetime.date(2019, 12, 8), datetime.date(2020, 1, 7))
# 2025-09-25 18:53:26,552 [INFO] >>> >>> Janela 12: (datetime.date(2020, 1, 8), datetime.date(2020, 2, 7))
# 2025-09-25 18:53:26,553 [INFO] >>> >>> Janela 13: (datetime.date(2020, 2, 8), datetime.date(2020, 3, 9))
# 2025-09-25 18:53:26,554 [INFO] >>> >>> Janela 14: (datetime.date(2020, 3, 10), datetime.date(2020, 4, 9))
# 2025-09-25 18:53:26,554 [INFO] >>> >>> Janela 15: (datetime.date(2020, 4, 10), datetime.date(2020, 5, 10))
# 2025-09-25 18:53:26,555 [INFO] >>> >>> Janela 16: (datetime.date(2020, 5, 11), datetime.date(2020, 6, 10))
# 2025-09-25 18:53:26,555 [INFO] >>> >>> Janela 17: (datetime.date(2020, 6, 11), datetime.date(2020, 7, 11))
# 2025-09-25 18:53:26,556 [INFO] >>> >>> Janela 18: (datetime.date(2020, 7, 12), datetime.date(2020, 8, 11))
# 2025-09-25 18:53:26,557 [INFO] >>> >>> Janela 19: (datetime.date(2020, 8, 12), datetime.date(2020, 9, 11))
# 2025-09-25 18:53:26,557 [INFO] >>> >>> Janela 20: (datetime.date(2020, 9, 12), datetime.date(2020, 10, 12))
# 2025-09-25 18:53:26,558 [INFO] >>> >>> Janela 21: (datetime.date(2020, 10, 13), datetime.date(2020, 11, 12))
# 2025-09-25 18:53:26,559 [INFO] >>> >>> Janela 22: (datetime.date(2020, 11, 13), datetime.date(2020, 12, 13))
# 2025-09-25 18:53:26,559 [INFO] >>> >>> Janela 23: (datetime.date(2020, 12, 14), datetime.date(2021, 1, 13))
# 2025-09-25 18:53:26,560 [INFO] >>> >>> Janela 24: (datetime.date(2021, 1, 14), datetime.date(2021, 2, 13))
# 2025-09-25 18:53:26,561 [INFO] >>> >>> Janela 25: (datetime.date(2021, 2, 14), datetime.date(2021, 3, 16))
# 2025-09-25 18:53:26,562 [INFO] >>> >>> Janela 26: (datetime.date(2021, 3, 17), datetime.date(2021, 4, 16))
# 2025-09-25 18:53:26,562 [INFO] >>> >>> Janela 27: (datetime.date(2021, 4, 17), datetime.date(2021, 5, 17))
# 2025-09-25 18:53:26,563 [INFO] >>> >>> Janela 28: (datetime.date(2021, 5, 18), datetime.date(2021, 6, 17))
# 2025-09-25 18:53:26,563 [INFO] >>> >>> Janela 29: (datetime.date(2021, 6, 18), datetime.date(2021, 7, 18))
# 2025-09-25 18:53:26,564 [INFO] >>> >>> Janela 30: (datetime.date(2021, 7, 19), datetime.date(2021, 8, 18))
# 2025-09-25 18:53:26,565 [INFO] >>> >>> Janela 31: (datetime.date(2021, 8, 19), datetime.date(2021, 9, 18))
# 2025-09-25 18:53:26,566 [INFO] >>> >>> Janela 32: (datetime.date(2021, 9, 19), datetime.date(2021, 10, 19))
# 2025-09-25 18:53:26,566 [INFO] >>> >>> Janela 33: (datetime.date(2021, 10, 20), datetime.date(2021, 11, 19))
# 2025-09-25 18:53:26,567 [INFO] >>> >>> Janela 34: (datetime.date(2021, 11, 20), datetime.date(2021, 12, 20))
# 2025-09-25 18:53:26,568 [INFO] >>> >>> Janela 35: (datetime.date(2021, 12, 21), datetime.date(2022, 1, 20))
# 2025-09-25 18:53:26,568 [INFO] >>> >>> Janela 36: (datetime.date(2022, 1, 21), datetime.date(2022, 2, 20))
# 2025-09-25 18:53:26,569 [INFO] >>> >>> Janela 37: (datetime.date(2022, 2, 21), datetime.date(2022, 3, 23))
# 2025-09-25 18:53:26,570 [INFO] >>> >>> Janela 38: (datetime.date(2022, 3, 24), datetime.date(2022, 4, 23))
# 2025-09-25 18:53:26,571 [INFO] >>> >>> Janela 39: (datetime.date(2022, 4, 24), datetime.date(2022, 5, 24))
# 2025-09-25 18:53:26,571 [INFO] >>> >>> Janela 40: (datetime.date(2022, 5, 25), datetime.date(2022, 6, 24))
# 2025-09-25 18:53:26,571 [INFO] >>> >>> Janela 41: (datetime.date(2022, 6, 25), datetime.date(2022, 7, 25))
# 2025-09-25 18:53:26,572 [INFO] >>> >>> Janela 42: (datetime.date(2022, 7, 26), datetime.date(2022, 8, 25))
# 2025-09-25 18:53:26,572 [INFO] >>> >>> Janela 43: (datetime.date(2022, 8, 26), datetime.date(2022, 9, 25))
# 2025-09-25 18:53:26,573 [INFO] >>> >>> Janela 44: (datetime.date(2022, 9, 26), datetime.date(2022, 10, 26))
# 2025-09-25 18:53:26,574 [INFO] >>> >>> Janela 45: (datetime.date(2022, 10, 27), datetime.date(2022, 11, 26))
# 2025-09-25 18:53:26,575 [INFO] >>> >>> Janela 46: (datetime.date(2022, 11, 27), datetime.date(2022, 12, 27))
# 2025-09-25 18:53:26,575 [INFO] >>> >>> Janela 47: (datetime.date(2022, 12, 28), datetime.date(2023, 1, 27))
# 2025-09-25 18:53:26,576 [INFO] >>> >>> Janela 48: (datetime.date(2023, 1, 28), datetime.date(2023, 1, 31))
# 2025-09-25 18:53:26,577 [INFO] >>> O download dos discursos será realizado em 48 intervalos
# 2025-09-25 18:53:26,577 [INFO] >>> Iniciando download dos discursos em 48 intervalos
# 2025-09-25 18:53:26,578 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190201/20190303.json
# 2025-09-25 18:53:27,310 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:27,315 [INFO] >>> >>> Discursos extraídos: 1
# 2025-09-25 18:53:27,315 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190304/20190403.json
# 2025-09-25 18:53:27,590 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:27,595 [INFO] >>> >>> Discursos extraídos: 2
# 2025-09-25 18:53:27,596 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190404/20190504.json
# 2025-09-25 18:53:27,736 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:27,740 [INFO] >>> >>> Discursos extraídos: 3
# 2025-09-25 18:53:27,741 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190505/20190604.json
# 2025-09-25 18:53:27,887 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:27,892 [INFO] >>> >>> Discursos extraídos: 4
# 2025-09-25 18:53:27,894 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190605/20190705.json
# 2025-09-25 18:53:28,037 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,042 [INFO] >>> >>> Discursos extraídos: 5
# 2025-09-25 18:53:28,043 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190706/20190805.json
# 2025-09-25 18:53:28,186 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,189 [INFO] >>> >>> Discursos extraídos: 6
# 2025-09-25 18:53:28,190 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190806/20190905.json
# 2025-09-25 18:53:28,334 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,339 [INFO] >>> >>> Discursos extraídos: 7
# 2025-09-25 18:53:28,340 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190906/20191006.json
# 2025-09-25 18:53:28,483 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,488 [INFO] >>> >>> Discursos extraídos: 8
# 2025-09-25 18:53:28,489 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191007/20191106.json
# 2025-09-25 18:53:28,665 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,671 [INFO] >>> >>> Discursos extraídos: 9
# 2025-09-25 18:53:28,671 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191107/20191207.json
# 2025-09-25 18:53:28,814 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,819 [INFO] >>> >>> Discursos extraídos: 10
# 2025-09-25 18:53:28,819 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191208/20200107.json
# 2025-09-25 18:53:28,963 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:28,967 [INFO] >>> >>> Discursos extraídos: 11
# 2025-09-25 18:53:28,968 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200108/20200207.json
# 2025-09-25 18:53:29,106 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,109 [INFO] >>> >>> Discursos extraídos: 12
# 2025-09-25 18:53:29,110 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200208/20200309.json
# 2025-09-25 18:53:29,250 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,255 [INFO] >>> >>> Discursos extraídos: 13
# 2025-09-25 18:53:29,255 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200310/20200409.json
# 2025-09-25 18:53:29,395 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,398 [INFO] >>> >>> Discursos extraídos: 14
# 2025-09-25 18:53:29,399 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200410/20200510.json
# 2025-09-25 18:53:29,540 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,543 [INFO] >>> >>> Discursos extraídos: 15
# 2025-09-25 18:53:29,544 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200511/20200610.json
# 2025-09-25 18:53:29,686 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,694 [INFO] >>> >>> Discursos extraídos: 16
# 2025-09-25 18:53:29,694 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200611/20200711.json
# 2025-09-25 18:53:29,834 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:29,837 [INFO] >>> >>> Discursos extraídos: 17
# 2025-09-25 18:53:29,838 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200712/20200811.json
# 2025-09-25 18:53:30,004 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,007 [INFO] >>> >>> Discursos extraídos: 18
# 2025-09-25 18:53:30,007 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200812/20200911.json
# 2025-09-25 18:53:30,146 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,149 [INFO] >>> >>> Discursos extraídos: 19
# 2025-09-25 18:53:30,149 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200912/20201012.json
# 2025-09-25 18:53:30,288 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,290 [INFO] >>> >>> Discursos extraídos: 20
# 2025-09-25 18:53:30,291 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201013/20201112.json
# 2025-09-25 18:53:30,431 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,437 [INFO] >>> >>> Discursos extraídos: 21
# 2025-09-25 18:53:30,439 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201113/20201213.json
# 2025-09-25 18:53:30,579 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,581 [INFO] >>> >>> Discursos extraídos: 22
# 2025-09-25 18:53:30,582 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201214/20210113.json
# 2025-09-25 18:53:30,721 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,724 [INFO] >>> >>> Discursos extraídos: 23
# 2025-09-25 18:53:30,725 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210114/20210213.json
# 2025-09-25 18:53:30,866 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:30,869 [INFO] >>> >>> Discursos extraídos: 24
# 2025-09-25 18:53:30,870 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210214/20210316.json
# 2025-09-25 18:53:31,011 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,017 [INFO] >>> >>> Discursos extraídos: 25
# 2025-09-25 18:53:31,019 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210317/20210416.json
# 2025-09-25 18:53:31,162 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,166 [INFO] >>> >>> Discursos extraídos: 26
# 2025-09-25 18:53:31,167 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210417/20210517.json
# 2025-09-25 18:53:31,311 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,321 [INFO] >>> >>> Discursos extraídos: 27
# 2025-09-25 18:53:31,322 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210518/20210617.json
# 2025-09-25 18:53:31,464 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,469 [INFO] >>> >>> Discursos extraídos: 28
# 2025-09-25 18:53:31,469 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210618/20210718.json
# 2025-09-25 18:53:31,611 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,616 [INFO] >>> >>> Discursos extraídos: 29
# 2025-09-25 18:53:31,616 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210719/20210818.json
# 2025-09-25 18:53:31,775 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,781 [INFO] >>> >>> Discursos extraídos: 30
# 2025-09-25 18:53:31,782 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210819/20210918.json
# 2025-09-25 18:53:31,927 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:31,935 [INFO] >>> >>> Discursos extraídos: 31
# 2025-09-25 18:53:31,936 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210919/20211019.json
# 2025-09-25 18:53:32,086 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,098 [INFO] >>> >>> Discursos extraídos: 32
# 2025-09-25 18:53:32,099 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211020/20211119.json
# 2025-09-25 18:53:32,244 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,252 [INFO] >>> >>> Discursos extraídos: 33
# 2025-09-25 18:53:32,253 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211120/20211220.json
# 2025-09-25 18:53:32,401 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,415 [INFO] >>> >>> Discursos extraídos: 34
# 2025-09-25 18:53:32,416 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211221/20220120.json
# 2025-09-25 18:53:32,553 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,556 [INFO] >>> >>> Discursos extraídos: 35
# 2025-09-25 18:53:32,556 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220121/20220220.json
# 2025-09-25 18:53:32,701 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,706 [INFO] >>> >>> Discursos extraídos: 36
# 2025-09-25 18:53:32,706 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220221/20220323.json
# 2025-09-25 18:53:32,851 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:32,861 [INFO] >>> >>> Discursos extraídos: 37
# 2025-09-25 18:53:32,862 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220324/20220423.json
# 2025-09-25 18:53:33,005 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,011 [INFO] >>> >>> Discursos extraídos: 38
# 2025-09-25 18:53:33,012 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220424/20220524.json
# 2025-09-25 18:53:33,161 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,170 [INFO] >>> >>> Discursos extraídos: 39
# 2025-09-25 18:53:33,170 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220525/20220624.json
# 2025-09-25 18:53:33,317 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,326 [INFO] >>> >>> Discursos extraídos: 40
# 2025-09-25 18:53:33,326 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220625/20220725.json
# 2025-09-25 18:53:33,470 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,475 [INFO] >>> >>> Discursos extraídos: 41
# 2025-09-25 18:53:33,476 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220726/20220825.json
# 2025-09-25 18:53:33,617 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,621 [INFO] >>> >>> Discursos extraídos: 42
# 2025-09-25 18:53:33,622 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220826/20220925.json
# 2025-09-25 18:53:33,765 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,771 [INFO] >>> >>> Discursos extraídos: 43
# 2025-09-25 18:53:33,773 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220926/20221026.json
# 2025-09-25 18:53:33,914 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:33,918 [INFO] >>> >>> Discursos extraídos: 44
# 2025-09-25 18:53:33,918 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221027/20221126.json
# 2025-09-25 18:53:34,058 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:34,061 [INFO] >>> >>> Discursos extraídos: 45
# 2025-09-25 18:53:34,062 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221127/20221227.json
# 2025-09-25 18:53:34,211 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:34,227 [INFO] >>> >>> Discursos extraídos: 46
# 2025-09-25 18:53:34,231 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221228/20230127.json
# 2025-09-25 18:53:34,369 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:34,372 [INFO] >>> >>> Discursos extraídos: 47
# 2025-09-25 18:53:34,373 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20230128/20230131.json
# 2025-09-25 18:53:34,509 [INFO] >>> >>> Extraindo discurso
# 2025-09-25 18:53:34,532 [INFO] >>> Discursos recuperados: 15729
# 2025-09-25 18:53:34,536 [INFO] Lista de discursos recuperados: 15729
# 2025-09-25 18:53:34,537 [INFO] Prepando discursos para download
# 2025-09-25 18:53:34,578 [INFO] Discursos com link para download do texto integral 15729
# 2025-09-25 18:53:34,578 [INFO] Iniciando download do texto integral do discurso com link para texto integral: 15729
# 2025-09-25 18:53:34,580 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451286
# 2025-09-25 18:53:34,580 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451285
# 2025-09-25 18:53:34,581 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451205
# 2025-09-25 18:53:34,584 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451203
# 2025-09-25 18:53:34,584 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451202
# 2025-09-25 18:53:34,585 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451200
# 2025-09-25 18:53:34,590 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451195
# 2025-09-25 18:53:34,591 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451194
# 2025-09-25 18:53:34,764 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451193
# 2025-09-25 18:53:34,918 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451192
# 2025-09-25 18:53:35,165 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451190
# 2025-09-25 18:53:35,251 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451183
# 2025-09-25 18:53:35,420 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451181
# 2025-09-25 18:53:35,429 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451179
# 2025-09-25 18:53:35,472 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451165
# 2025-09-25 18:53:35,439 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451175
# 2025-09-25 18:53:35,449 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451173
# 2025-09-25 18:53:35,453 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451171
# 2025-09-25 18:53:35,462 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451167
# 2025-09-25 18:53:35,437 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451177
# 2025-09-25 18:53:35,673 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451163
# 2025-09-25 18:53:35,675 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451161
# 2025-09-25 18:53:35,676 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451159
# 2025-09-25 18:53:35,695 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451284
# 2025-09-25 18:53:35,718 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451283
# 2025-09-25 18:53:35,860 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451259
# 2025-09-25 18:53:35,869 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451257
# 2025-09-25 18:53:35,888 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451250
# 2025-09-25 18:53:35,895 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451237
# 2025-09-25 18:53:35,906 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451235
# 2025-09-25 18:53:35,959 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451230
# 2025-09-25 18:53:36,007 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451225
# 2025-09-25 18:53:36,019 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451212
# 2025-09-25 18:53:36,049 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451211
# 2025-09-25 18:53:36,090 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451210
# 2025-09-25 18:53:36,092 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451209
# 2025-09-25 18:53:36,095 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451208
# 2025-09-25 18:53:36,097 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451155
# 2025-09-25 18:53:36,101 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451153
# 2025-09-25 18:53:36,144 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451152
# 2025-09-25 18:53:36,160 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451151
# 2025-09-25 18:53:36,186 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451148
# 2025-09-25 18:53:36,228 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451147
# 2025-09-25 18:53:36,232 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451146
# 2025-09-25 18:53:36,235 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451120
# 2025-09-25 18:53:36,236 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451116
# 2025-09-25 18:53:36,241 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451112
# 2025-09-25 18:53:36,282 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451110
# 2025-09-25 18:53:36,299 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451108
# 2025-09-25 18:53:36,328 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451106
# 2025-09-25 18:53:36,366 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451143
# 2025-09-25 18:53:36,371 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451142
# 2025-09-25 18:53:36,373 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451141
# 2025-09-25 18:53:36,377 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451139
# 2025-09-25 18:53:36,381 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451138
# 2025-09-25 18:53:36,420 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451137
# 2025-09-25 18:53:36,443 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451136
# 2025-09-25 18:53:36,468 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451135
# 2025-09-25 18:53:36,506 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451134
# 2025-09-25 18:53:36,509 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451133
# 2025-09-25 18:53:36,513 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451131
# 2025-09-25 18:53:36,517 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451103
# 2025-09-25 18:53:36,520 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451102
# 2025-09-25 18:53:36,557 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451101
# 2025-09-25 18:53:36,583 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451100
# 2025-09-25 18:53:36,604 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451099
# 2025-09-25 18:53:36,647 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451084
# 2025-09-25 18:53:36,650 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451080
# 2025-09-25 18:53:36,652 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451066
# 2025-09-25 18:53:36,658 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451061
# 2025-09-25 18:53:36,662 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451060
# 2025-09-25 18:53:36,695 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451057
# 2025-09-25 18:53:36,723 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451056
# 2025-09-25 18:53:36,745 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451055
# 2025-09-25 18:53:36,789 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451054
# 2025-09-25 18:53:36,792 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451053
# 2025-09-25 18:53:36,793 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451052
# 2025-09-25 18:53:36,797 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451050
# 2025-09-25 18:53:36,803 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451049
# 2025-09-25 18:53:36,831 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451047
# 2025-09-25 18:53:36,863 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451046
# 2025-09-25 18:53:36,883 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451045
# 2025-09-25 18:53:36,928 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451043
# 2025-09-25 18:53:36,930 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451040
# 2025-09-25 18:53:36,937 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451037
# 2025-09-25 18:53:36,943 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451031
# 2025-09-25 18:53:36,946 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451011
# 2025-09-25 18:53:37,003 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451008
# 2025-09-25 18:53:37,010 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451006
# 2025-09-25 18:53:37,023 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450995
# 2025-09-25 18:53:37,068 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450994
# 2025-09-25 18:53:37,071 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450992
# 2025-09-25 18:53:37,081 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450989
# 2025-09-25 18:53:37,082 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450988
# 2025-09-25 18:53:37,097 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450987
# 2025-09-25 18:53:37,142 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450985
# 2025-09-25 18:53:37,145 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451123
# 2025-09-25 18:53:37,159 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451122
# 2025-09-25 18:53:37,207 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450982
# 2025-09-25 18:53:37,211 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450976
# 2025-09-25 18:53:37,219 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450974
# 2025-09-25 18:53:37,223 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450972
# 2025-09-25 18:53:37,236 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450970
# 2025-09-25 18:53:37,283 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450968
# 2025-09-25 18:53:37,284 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450966
# 2025-09-25 18:53:37,298 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450964
# 2025-09-25 18:53:37,348 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450963
# 2025-09-25 18:53:37,352 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450941
# 2025-09-25 18:53:37,364 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450940
# 2025-09-25 18:53:37,369 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450939
# 2025-09-25 18:53:37,377 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450938
# 2025-09-25 18:53:37,425 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450937
# 2025-09-25 18:53:37,433 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450936
# 2025-09-25 18:53:37,436 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450934
# 2025-09-25 18:53:37,488 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450933
# 2025-09-25 18:53:37,491 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450958
# 2025-09-25 18:53:37,507 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450957
# 2025-09-25 18:53:37,508 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450956
# 2025-09-25 18:53:37,525 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450955
# 2025-09-25 18:53:37,566 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450954
# 2025-09-25 18:53:37,572 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450953
# 2025-09-25 18:53:37,576 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450952
# 2025-09-25 18:53:37,629 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450951
# 2025-09-25 18:53:37,630 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450950
# 2025-09-25 18:53:37,646 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450949
# 2025-09-25 18:53:37,652 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450948
# 2025-09-25 18:53:37,667 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450946
# 2025-09-25 18:53:37,707 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450945
# 2025-09-25 18:53:37,709 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450944
# 2025-09-25 18:53:37,713 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450962
# 2025-09-25 18:53:37,769 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450854
# 2025-09-25 18:53:37,772 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450850
# 2025-09-25 18:53:37,785 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450846
# 2025-09-25 18:53:37,795 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450842
# 2025-09-25 18:53:37,809 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450838
# 2025-09-25 18:53:37,846 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450836
# 2025-09-25 18:53:37,854 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450832
# 2025-09-25 18:53:37,855 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450830
# 2025-09-25 18:53:37,909 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450826
# 2025-09-25 18:53:37,915 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450822
# 2025-09-25 18:53:37,921 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450820
# 2025-09-25 18:53:37,940 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450818
# 2025-09-25 18:53:37,949 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450816
# 2025-09-25 18:53:37,991 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450814
# 2025-09-25 18:53:37,999 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450961
# 2025-09-25 18:53:38,002 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450930
# 2025-09-25 18:53:38,050 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450929
# 2025-09-25 18:53:38,055 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450928
# 2025-09-25 18:53:38,062 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450926
# 2025-09-25 18:53:38,084 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450925
# 2025-09-25 18:53:38,089 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450923
# 2025-09-25 18:53:38,141 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450922
# 2025-09-25 18:53:38,142 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450775
# 2025-09-25 18:53:38,144 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450768
# 2025-09-25 18:53:38,198 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450766
# 2025-09-25 18:53:38,205 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450764
# 2025-09-25 18:53:38,207 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450762
# 2025-09-25 18:53:38,235 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450760
# 2025-09-25 18:53:38,241 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450758
# 2025-09-25 18:53:38,294 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450757
# 2025-09-25 18:53:38,299 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450755
# 2025-09-25 18:53:38,306 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450753
# 2025-09-25 18:53:38,345 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450751
# 2025-09-25 18:53:38,351 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450749
# 2025-09-25 18:53:38,349 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450750
# 2025-09-25 18:53:38,391 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450748
# 2025-09-25 18:53:38,397 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450746
# 2025-09-25 18:53:38,447 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450740
# 2025-09-25 18:53:38,454 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450737
# 2025-09-25 18:53:38,473 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450736
# 2025-09-25 18:53:38,489 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450735
# 2025-09-25 18:53:38,491 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450960
# 2025-09-25 18:53:38,493 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450696
# 2025-09-25 18:53:38,537 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450694
# 2025-09-25 18:53:38,541 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450690
# 2025-09-25 18:53:38,588 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450686
# 2025-09-25 18:53:38,594 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450685
# 2025-09-25 18:53:38,612 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450684
# 2025-09-25 18:53:38,630 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450682
# 2025-09-25 18:53:38,633 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450680
# 2025-09-25 18:53:38,678 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450678
# 2025-09-25 18:53:38,725 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450676
# 2025-09-25 18:53:38,771 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450674
# 2025-09-25 18:53:38,772 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450672
# 2025-09-25 18:53:38,795 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450732
# 2025-09-25 18:53:38,819 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450731
# 2025-09-25 18:53:38,908 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450730
# 2025-09-25 18:53:38,911 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450728
# 2025-09-25 18:53:38,915 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450726
# 2025-09-25 18:53:38,935 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450724
# 2025-09-25 18:53:38,959 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450722
# 2025-09-25 18:53:39,045 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450720
# 2025-09-25 18:53:39,048 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450718
# 2025-09-25 18:53:39,075 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450716
# 2025-09-25 18:53:39,098 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450714
# 2025-09-25 18:53:39,186 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450712
# 2025-09-25 18:53:39,191 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450710
# 2025-09-25 18:53:39,215 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450708
# 2025-09-25 18:53:39,241 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450706
# 2025-09-25 18:53:39,324 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450704
# 2025-09-25 18:53:39,327 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450702
# 2025-09-25 18:53:39,357 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450700
# 2025-09-25 18:53:39,381 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450698
# 2025-09-25 18:53:39,463 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450660
# 2025-09-25 18:53:39,467 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450641
# 2025-09-25 18:53:39,497 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450636
# 2025-09-25 18:53:39,520 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450635
# 2025-09-25 18:53:39,601 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450634
# 2025-09-25 18:53:39,604 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450633
# 2025-09-25 18:53:39,636 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450631
# 2025-09-25 18:53:39,659 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450629
# 2025-09-25 18:53:39,737 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450619
# 2025-09-25 18:53:39,743 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450618
# 2025-09-25 18:53:39,777 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450617
# 2025-09-25 18:53:39,799 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450616
# 2025-09-25 18:53:39,876 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450615
# 2025-09-25 18:53:39,880 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450613
# 2025-09-25 18:53:39,917 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450612
# 2025-09-25 18:53:39,941 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450611
# 2025-09-25 18:53:40,013 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450610
# 2025-09-25 18:53:40,018 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450609
# 2025-09-25 18:53:40,056 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450607
# 2025-09-25 18:53:40,081 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450606
# 2025-09-25 18:53:40,156 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450605
# 2025-09-25 18:53:40,158 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450604
# 2025-09-25 18:53:40,198 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450603
# 2025-09-25 18:53:40,221 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450601
# 2025-09-25 18:53:40,293 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450600
# 2025-09-25 18:53:40,294 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450599
# 2025-09-25 18:53:40,338 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450598
# 2025-09-25 18:53:40,361 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450574
# 2025-09-25 18:53:40,430 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450533
# 2025-09-25 18:53:40,440 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450526
# 2025-09-25 18:53:40,477 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450524
# 2025-09-25 18:53:40,501 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450523
# 2025-09-25 18:53:40,572 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450514
# 2025-09-25 18:53:40,578 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450513
# 2025-09-25 18:53:40,618 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450512
# 2025-09-25 18:53:40,643 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450511
# 2025-09-25 18:53:40,709 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450510
# 2025-09-25 18:53:40,721 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450509
# 2025-09-25 18:53:40,763 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450508
# 2025-09-25 18:53:40,782 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450506
# 2025-09-25 18:53:40,846 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450504
# 2025-09-25 18:53:40,858 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450503
# 2025-09-25 18:53:40,903 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450497
# 2025-09-25 18:53:40,922 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450491
# 2025-09-25 18:53:40,983 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450486
# 2025-09-25 18:53:40,995 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450483
# 2025-09-25 18:53:41,046 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450482
# 2025-09-25 18:53:41,062 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450481
# 2025-09-25 18:53:41,119 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450480
# 2025-09-25 18:53:41,132 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450476
# 2025-09-25 18:53:41,185 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450474
# 2025-09-25 18:53:41,203 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450439
# 2025-09-25 18:53:41,255 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450408
# 2025-09-25 18:53:41,270 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450399
# 2025-09-25 18:53:41,328 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450398
# 2025-09-25 18:53:41,343 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450397
# 2025-09-25 18:53:41,391 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450396
# 2025-09-25 18:53:41,407 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450395
# 2025-09-25 18:53:41,467 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450394
# 2025-09-25 18:53:41,481 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450392
# 2025-09-25 18:53:41,527 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450391
# 2025-09-25 18:53:41,543 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450390
# ...
# 2025-09-25 19:01:09,475 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494476
# 2025-09-25 19:01:09,481 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494475
# 2025-09-25 19:01:09,535 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494474
# 2025-09-25 19:01:09,609 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494472
# 2025-09-25 19:01:09,611 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494471
# 2025-09-25 19:01:09,612 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494470
# 2025-09-25 19:01:09,618 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494469
# 2025-09-25 19:01:09,674 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494468
# 2025-09-25 19:01:09,747 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494466
# 2025-09-25 19:01:09,749 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494465
# 2025-09-25 19:01:09,752 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494464
# 2025-09-25 19:01:09,756 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494512
# 2025-09-25 19:01:09,815 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494511
# 2025-09-25 19:01:09,884 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494510
# 2025-09-25 19:01:09,886 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494509
# 2025-09-25 19:01:09,894 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494508
# 2025-09-25 19:01:09,897 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494507
# 2025-09-25 19:01:09,956 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494506
# 2025-09-25 19:01:10,021 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494505
# 2025-09-25 19:01:10,025 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494504
# 2025-09-25 19:01:10,032 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494503
# 2025-09-25 19:01:10,037 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494460
# 2025-09-25 19:01:10,096 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494458
# 2025-09-25 19:01:10,168 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494456
# 2025-09-25 19:01:10,172 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494454
# 2025-09-25 19:01:10,176 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494453
# 2025-09-25 19:01:10,183 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494452
# 2025-09-25 19:01:10,236 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494450
# 2025-09-25 19:01:10,308 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494449
# 2025-09-25 19:01:10,314 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494448
# 2025-09-25 19:01:10,317 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494446
# 2025-09-25 19:01:10,320 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494444
# 2025-09-25 19:01:10,375 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494442
# 2025-09-25 19:01:10,444 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494440
# 2025-09-25 19:01:10,453 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494439
# 2025-09-25 19:01:10,455 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494438
# 2025-09-25 19:01:10,457 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494436
# 2025-09-25 19:01:10,515 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494435
# 2025-09-25 19:01:10,580 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494434
# 2025-09-25 19:01:10,591 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494433
# 2025-09-25 19:01:10,594 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494432
# 2025-09-25 19:01:10,596 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494431
# 2025-09-25 19:01:10,655 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494430
# 2025-09-25 19:01:10,716 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494429
# 2025-09-25 19:01:10,730 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494428
# 2025-09-25 19:01:10,732 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494427
# 2025-09-25 19:01:10,735 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494426
# 2025-09-25 19:01:10,794 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494425
# 2025-09-25 19:01:10,868 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494424
# 2025-09-25 19:01:10,872 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494423
# 2025-09-25 19:01:10,874 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494421
# 2025-09-25 19:01:10,883 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494418
# 2025-09-25 19:01:10,936 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494417
# 2025-09-25 19:01:11,005 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494416
# 2025-09-25 19:01:11,011 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494415
# 2025-09-25 19:01:11,013 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494414
# 2025-09-25 19:01:11,018 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494413
# 2025-09-25 19:01:11,076 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494412
# 2025-09-25 19:01:11,142 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494410
# 2025-09-25 19:01:11,148 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494409
# 2025-09-25 19:01:11,151 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494408
# 2025-09-25 19:01:11,159 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494407
# 2025-09-25 19:01:11,216 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494385
# 2025-09-25 19:01:11,281 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494384
# 2025-09-25 19:01:11,285 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494382
# 2025-09-25 19:01:11,289 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494381
# 2025-09-25 19:01:11,295 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494379
# 2025-09-25 19:01:11,355 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494377
# 2025-09-25 19:01:11,420 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494375
# 2025-09-25 19:01:11,423 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494373
# 2025-09-25 19:01:11,428 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494371
# 2025-09-25 19:01:11,431 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494369
# 2025-09-25 19:01:11,496 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494367
# 2025-09-25 19:01:11,557 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494366
# 2025-09-25 19:01:11,560 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494365
# 2025-09-25 19:01:11,566 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494363
# 2025-09-25 19:01:11,568 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494360
# 2025-09-25 19:01:11,636 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494358
# 2025-09-25 19:01:11,695 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494356
# 2025-09-25 19:01:11,697 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494355
# 2025-09-25 19:01:11,705 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494354
# 2025-09-25 19:01:11,709 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494350
# 2025-09-25 19:01:11,777 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494349
# 2025-09-25 19:01:11,833 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494348
# 2025-09-25 19:01:11,835 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494347
# 2025-09-25 19:01:11,850 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494346
# 2025-09-25 19:01:11,856 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494344
# 2025-09-25 19:01:11,918 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494342
# 2025-09-25 19:01:11,970 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494339
# 2025-09-25 19:01:11,972 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494337
# 2025-09-25 19:01:11,989 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494335
# 2025-09-25 19:01:11,994 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494333
# 2025-09-25 19:01:12,058 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494332
# 2025-09-25 19:01:12,106 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494331
# 2025-09-25 19:01:12,110 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494329
# 2025-09-25 19:01:12,128 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495362
# 2025-09-25 19:01:12,134 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495361
# 2025-09-25 19:01:12,202 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495359
# 2025-09-25 19:01:12,247 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495357
# 2025-09-25 19:01:12,249 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495355
# 2025-09-25 19:01:12,267 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495353
# 2025-09-25 19:01:12,271 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495351
# 2025-09-25 19:01:12,343 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495349
# 2025-09-25 19:01:12,387 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495348
# 2025-09-25 19:01:12,388 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495502
# 2025-09-25 19:01:12,406 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495501
# 2025-09-25 19:01:12,409 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495500
# 2025-09-25 19:01:12,483 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495499
# 2025-09-25 19:01:12,526 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495498
# 2025-09-25 19:01:12,527 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495497
# 2025-09-25 19:01:12,546 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495496
# 2025-09-25 19:01:12,549 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495494
# 2025-09-25 19:01:12,622 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495493
# 2025-09-25 19:01:12,665 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495491
# 2025-09-25 19:01:12,668 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495490
# 2025-09-25 19:01:12,683 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495489
# 2025-09-25 19:01:12,698 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495488
# 2025-09-25 19:01:12,763 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495487
# 2025-09-25 19:01:12,808 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495486
# 2025-09-25 19:01:12,809 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495485
# 2025-09-25 19:01:12,823 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495484
# 2025-09-25 19:01:12,837 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495483
# 2025-09-25 19:01:12,903 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495482
# 2025-09-25 19:01:12,947 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495481
# 2025-09-25 19:01:12,949 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495480
# 2025-09-25 19:01:12,959 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495479
# 2025-09-25 19:01:12,976 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495478
# 2025-09-25 19:01:13,044 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495477
# 2025-09-25 19:01:13,084 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495476
# 2025-09-25 19:01:13,087 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495475
# 2025-09-25 19:01:13,105 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495474
# 2025-09-25 19:01:13,114 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495473
# 2025-09-25 19:01:13,186 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495471
# 2025-09-25 19:01:13,222 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495469
# 2025-09-25 19:01:13,224 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495467
# 2025-09-25 19:01:13,241 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495466
# 2025-09-25 19:01:13,252 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495465
# 2025-09-25 19:01:13,327 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495464
# 2025-09-25 19:01:23,451 [INFO] Foi realizado o download dos textos de discursos: 15729
# 2025-09-25 19:01:23,470 [INFO] Textos no data frame final: 15729
# 2025-09-25 19:01:23,471 [INFO] Discursos por período: 15,729 linhas
# 2025-09-25 19:01:23,472 [INFO] Salvando arquivo com a lista dos discursos e os respectivos textos integrais
# 2025-09-25 19:01:23,473 [INFO] OK: 15039 textos baixados, 690 sem texto. Arquivo salvo em: _data/discursos_2019-02-01_2023-01-31.parquet
