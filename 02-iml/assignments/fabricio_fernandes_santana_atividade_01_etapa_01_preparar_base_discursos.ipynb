# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriciosantana/mcdia/blob/main/01-icd/assignments/01-preparar-base-discursos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # Relatório Preliminar – Preparação da Base de Discursos
#
# Fabrício Fernandes Santana
# Disciplina: Introdução ao Machine Learning – Mestrado em Administração Pública (2025.2)
#
# ## 1. Descrição da Base de Dados
# - **Fonte dos dados:** Portal de Dados Abertos do Senado Federal (https://legis.senado.leg.br/dadosabertos).
# - **Contextualização:** Pronunciamentos da 56ª Legislatura (fev/2019 a jan/2023) com metadados e texto integral, recuperados via API oficial.
# - **Objetivo da utilização:** Consolidar um arquivo único, auditável e reutilizável que sirva de insumo às análises exploratórias e modelagens das etapas seguintes.
# - **Problema de pesquisa:** Como caracterizar e automatizar a análise dos discursos parlamentares para apoiar diagnósticos sobre atuação partidária e agenda temática?
#
# ## 2. Dicionário de Dados
# O dicionário de dados está disponível em `dicionario_dados.xlsx`, com descrições completas, domínios esperados e observações de qualidade para as 30 variáveis da base.
#
# ## 3. Análises Descritivas Iniciais
#
# ### 3.1 Medidas de Posição e Dispersão
# A base consolidada reúne 15.729 pronunciamentos e 30 atributos. Foram identificados 32 partidos e 27 unidades da federação. Cada discurso apresenta em média 728 palavras (mediana de 464; mínimo 0; máximo 17.602), com desvio-padrão aproximado de 880 palavras. Cerca de 4,4% dos registros ficaram sem transcrição integral porque o arquivo não estava disponível (status HTTP 404).
#
# ### 3.2 Exploração Gráfica
# Esta etapa priorizou a engenharia de coleta. As visualizações serão detalhadas na Etapa 02; aqui apenas conferimos rapidamente o intervalo temporal (fev/2019 a jan/2023) e o volume por janela de download para validar o pipeline.
#
# ## 4. Discussão Preliminar
# A coleta evidenciou pontos de atenção: autores externos não recebem código parlamentar, partido ou UF; há heterogeneidade nas descrições de cargos e órgãos; e os 690 discursos sem texto exigem tratamento específico nas análises futuras. Apesar disso, a base resultante está consistente e auditável.
#
# ## 5. Próximos Passos
# - Validar o dicionário e complementar metadados se necessário.
# - Executar as análises exploratórias (Etapa 02) e preparar subconjuntos balanceados para as etapas supervisionada e não supervisionada.
# - Registrar logs de falha de download para reprocessamentos futuros junto ao portal do Senado.
#
# ## Referências
# - Portal de Dados Abertos do Senado Federal. Disponível em: https://legis.senado.leg.br/dadosabertos.

# %% [markdown]
# ## Anexo técnico – Preparação automatizada da base de discursos
#
# Ao final deste notebook é esperado que se tenha uma base de dados (arquivo parquet) no diretório _data. Para evitar fazer download de novos dados, é dado a opção de reaproveitar arquivo baixando anteriormente para o mesmo período de data.

# %% [markdown]
# ## Instalar dependências
#
# Instala as dependências necessárias para garantir que as bibliotecas de coleta e tratamento de dados estejam disponíveis ao longo do notebook.

# %%
# %pip install requests pandas pyarrow
# Out:
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (2.32.4)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: pyarrow in /usr/local/python/3.12.1/lib/python3.12/site-packages (21.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2025.7.9)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importar bibliotecas
#
# Carrega as bibliotecas necessárias para execução deste notebook.

# %%
import time
import datetime as dt
import logging
import csv
import requests
import pandas as pd
import re
from pathlib import Path
from typing import List, Dict, Any
from requests.adapters import HTTPAdapter, Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from pprint import pformat

# %% [markdown]
# ## Inicializar variáveis globais
#
# Configura parâmetros globais de conexão, intervalo padrão e diretórios de saída.

# %%
BASE = "https://legis.senado.leg.br/dadosabertos/"

TIMEOUT_JSON = 90
TIMEOUT_TXT  = 60
RETRY_TOTAL  = 8
RETRY_BACKOFF = 0.6
STATUS_FORCELIST = [429, 500, 502, 503, 504]

DEFAULT_INI = dt.date(2019, 3, 29)
DEFAULT_FIM = dt.date(2019, 3, 31)

DATA_DIR = Path("_data")
DATA_DIR.mkdir(exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)
log = logging.getLogger("discursos")

# %% [markdown]
# ## Definir métodos utilitários
#
# Define métodos utilitários que serão utilizados na preparação da base de dados

# %% [markdown]
# ### Criar sessão HTTP
#
# Os dados são obtidos do portal de dados abertos do Senado por meio de requisições HTTP.

# %%
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=RETRY_TOTAL,
        backoff_factor=RETRY_BACKOFF,
        status_forcelist=STATUS_FORCELIST,
        allowed_methods=["GET"],
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))

    log.info(f">>> Headers: {pformat(dict(s.headers))}")
    log.info(f">>> Cookies: {s.cookies}")
    log.info(f">>> Auth: {s.auth}")

    return s

log.info(f"Construindo sessão HTTP")
sess = make_session()
# Out:
# 2025-10-10 17:41:33,627 [INFO] Construindo sessão HTTP
# 2025-10-10 17:41:33,629 [INFO] >>> Headers: {'Accept': '*/*',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Connection': 'keep-alive',
#  'User-Agent': 'python-requests/2.32.4'}
# 2025-10-10 17:41:33,630 [INFO] >>> Cookies: <RequestsCookieJar[]>
# 2025-10-10 17:41:33,630 [INFO] >>> Auth: None

# %% [markdown]
# ### Montar intervalo de datas
#
# As requisições à API do Senado só pode ser realizada para intervalos de 31 dias. A partir de um intervalo de datas, o método abaixo criar intervalos no período pré-definido.

# %%
def montar_intervalo_de_datas(start: dt.date, end: dt.date, days_per_window: int = 31) -> List[tuple]:
    """Gera janelas [ini, fim] inclusive, com no máx. 'days_per_window' dias cada."""

    log.info(f">>> Montando intervalos de {days_per_window} dias para fazer download dos discursos em blocos")

    windows = []
    cur = start
    one_day = dt.timedelta(days=1)

    while cur <= end:
        w_end = min(cur + dt.timedelta(days=days_per_window - 1), end)
        windows.append((cur, w_end))
        log.info(f">>> >>> Janela {len(windows)}: {(cur, w_end)}")
        cur = w_end + one_day

    log.info(f">>> O download dos discursos será realizado em {len(windows)} intervalos")
    return windows

# %% [markdown]
# ### Extrair discurso
#
# Extrai os pronunciamentos úteis das respostas JSON obtidas. A função percorre dicionários e listas recursivamente, reunindo todos os itens associados à chave `Pronunciamento`.

# %%
def extrair_discurso(obj: Any) -> List[Dict[str, Any]]:
    """
    Procura, recursivamente, qualquer lista sob a chave 'Pronunciamento'.
    Isso torna o parser resiliente a pequenas mudanças de envelope.
    """
    out = []

    def rec(x):
        if isinstance(x, dict):
            for k, v in x.items():
                if isinstance(k, str) and k.lower() == "pronunciamento" and isinstance(v, list):
                    out.extend(v)
                else:
                    rec(v)
        elif isinstance(x, list):
            for it in x:
                rec(it)

    rec(obj)
    return out

# %% [markdown]
# ### Recuperar discurso de um período
#
# Baixa os discursos do período solicitado e consolidando-os em um DataFrame. O algoritmo percorre as janelas de datas, faz requisições à API, normaliza os resultados com `pandas` e concatena os blocos retornados.

# %%
def recuperar_lista_discursos_por_periodo(data_inicio: dt.date, data_fim: dt.date, sleep_s: float = 0.0) -> pd.DataFrame:
    """
    Busca discursos do Plenário por janelas de data, agregando tudo num DataFrame.
    Endpoint: /plenario/lista/discursos/{AAAAMMDD}/{AAAAMMDD}.json
    """

    log.info(f">>> Preparando intervalos para download dos discursos de {data_inicio} a {data_fim}")
    windows = montar_intervalo_de_datas(data_inicio, data_fim, days_per_window=31)  # janelas de ~1 mês

    log.info(f">>> Iniciando download dos discursos em {len(windows)} intervalos")
    all_rows = []

    for i, (data_ini, data_fim) in enumerate(windows, 1):
        url = f"{BASE}plenario/lista/discursos/{data_ini.strftime('%Y%m%d')}/{data_fim.strftime('%Y%m%d')}.json"

        log.info(f">>> >>> GET: {url}")
        r = sess.get(url, headers={"Accept": "application/json"}, timeout=TIMEOUT_JSON)
        r.raise_for_status()
        j = r.json()

        log.info(f">>> >>> Extraindo discurso")
        pron = extrair_discurso(j)
        if pron:
            # flatten resiliente
            df = pd.json_normalize(pron, sep=".")
            # anexa janela de coleta (útil para auditoria)
            df["__janela_inicio"] = data_ini.isoformat()
            df["__janela_fim"] = data_fim.isoformat()
            all_rows.append(df)
            log.info(f">>> >>> Discursos extraídos: {len(all_rows)}")

        if sleep_s:
            time.sleep(sleep_s)

    if not all_rows:
        return pd.DataFrame()

    df_all = pd.concat(all_rows, ignore_index=True, sort=False)
    log.info(f">>> Discursos recuperados: {len(df_all)}")

    return df_all

# %% [markdown]
# ### Recuperar texto integral de um discurso
#
# Obtém e higieniza o texto integral de cada discurso antes da análise. A rotina faz a requisição ao link de texto, trata códigos de status, remove excessos de espaço e retorna um dicionário com o resultado de cada tentativa.

# %%
def recuperar_texto_discurso(codigo_pron: str, url_txt: str) -> dict:
    out = {"CodigoPronunciamento": codigo_pron, "TextoDiscursoIntegral": "", "ok": False, "status": None, "msg": ""}

    try:
        log.info(f">>> GET: {url_txt}")
        r = sess.get(url_txt, timeout=TIMEOUT_TXT, headers={"Accept": "text/plain, */*;q=0.1"}, allow_redirects=True)
        out["status"] = r.status_code

        # log auxiliar para diagnosticar
        ct = (r.headers.get("Content-Type") or "").lower()
        if r.status_code == 404:
            out["msg"] = "404 (sem texto integral)";  return out
        if r.status_code == 204:
            out["msg"] = "204 (sem conteúdo)";        return out

        r.raise_for_status()

        # conteúdo
        txt = r.text or ""
        # limpeza leve (uso de re.sub, não r.sub)
        txt = re.sub(r"\s+\n", "\n", txt)
        txt = re.sub(r"[ \t]+", " ", txt).strip()

        # proteção: se veio vazio, registra e sai
        if not txt:
            out["msg"] = f"vazio (Content-Type={ct})"
            return out

        out["ok"] = True
        out["TextoDiscursoIntegral"] = txt
        return out

    except Exception as e:
        out["msg"] = str(e)
        return out

# %% [markdown]
# ### Preparar discurso para download
#
# Prepara a lista de discursos para a etapa de download do texto integral. O código renomeia colunas conforme necessário, normaliza strings e filtra apenas linhas com URLs válidas para o texto integral.

# %%
def preparar_discursos_para_download(
    df_discursos: pd.DataFrame,
    cols_necessarias=("TextoIntegralTxt", "CodigoPronunciamento"),
    inplace: bool = False
) -> pd.DataFrame:
    """
    - Faz rename tolerante das colunas necessárias para os nomes canônicos em `cols_necessarias`.
    - Converte para string e strip.
    - Retorna APENAS as linhas com URL válida em `TextoIntegralTxt` (http/https).
    """
    df = df_discursos if inplace else df_discursos.copy()

    # 1) garantir/renomear colunas
    ren = {}
    for alvo in cols_necessarias:
        col_real = _match_col(df, alvo)
        if col_real != alvo:
            ren[col_real] = alvo
    if ren:
        df = df.rename(columns=ren)

    # 2) normalizar valores
    for alvo in cols_necessarias:
        df[alvo] = df[alvo].astype(str).str.strip()

    # 3) filtrar URLs válidas
    df_filtrado = df[df["TextoIntegralTxt"].str.startswith(("http://", "https://"), na=False)].copy()

    return df_filtrado

def _match_col(df: pd.DataFrame, alvo: str) -> str:
    """
    Tenta encontrar em df.columns a coluna equivalente a `alvo`.
    Estratégia: match exato (case-insensitive) -> contém (case-insensitive).
    Retorna o nome da coluna encontrada ou levanta KeyError.
    """
    cols = list(df.columns)
    # 1) exato (case-insensitive)
    for c in cols:
        if c.lower() == alvo.lower():
            return c
    # 2) contém (case-insensitive)
    candidatos = [c for c in cols if alvo.lower() in c.lower()]
    if candidatos:
        # prioriza o mais curto (geralmente o nome mais "limpo")
        return sorted(candidatos, key=len)[0]
    raise KeyError(f"Coluna obrigatória não encontrada: {alvo}. Disponíveis: {cols}")

# %% [markdown]
# ### Fazer download texto discurso
#
# Executar em paralelo o download dos textos dos discursos selecionados. A função usa `ThreadPoolExecutor` para chamar o `fetch_fn` por linha, captura exceções e reúne os resultados em um DataFrame consolidado.

# %%
def fazer_download_texto_discursos(
    df_download,
    fetch_fn,                 # ex.: fetch_and_save_txt(codigo_pron, url_txt)
    max_workers: int = 8
):
    """
    Executa fetch_fn(CodigoPronunciamento, TextoIntegralTxt) em paralelo
    para cada linha de df_download e retorna a lista 'resultados'.

    - fetch_fn deve retornar um dict (ex.: {"CodigoPronunciamento":..., "ok":..., ...})
    """
    resultados = []
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        futs = {
            ex.submit(fetch_fn, row["CodigoPronunciamento"], row["TextoIntegralTxt"]): row
            for _, row in df_download.iterrows()
        }
        for fut in as_completed(futs):
            row = futs[fut]
            try:
                resultados.append(fut.result())
            except Exception as e:
                resultados.append({
                    "CodigoPronunciamento": row.get("CodigoPronunciamento"),
                    "ok": False,
                    "msg": str(e),
                })
    return pd.DataFrame(resultados)

# %% [markdown]
# ### Solicitar intervalo de datas
#
# Permite que o usuário defina o intervalo de datas de interesse com validações básicas. O código lê entradas interativas, aceita múltiplos formatos e garante que as datas estejam ordenadas antes de prosseguir.

# %%
def ler_intervalo_datas() -> tuple[dt.date, dt.date]:
    print("Informe o intervalo (ENTER para usar padrão 2019-03-29 → 2019-03-31).")
    s_ini = input("Data inicial [2019-03-29]: ").strip()
    s_fim = input("Data final   [2019-03-31]: ").strip()

    ini = _parse_data(s_ini) if s_ini else DEFAULT_INI
    fim = _parse_data(s_fim) if s_fim else DEFAULT_FIM
    if fim < ini:
        ini, fim = fim, ini
        print(f"Aviso: datas invertidas. Usando {ini} → {fim}.")
    return ini, fim

def _parse_data(s: str) -> dt.date:
    s = (s or "").strip()
    for fmt in ("%Y-%m-%d", "%d/%m/%Y"):
        try:
            return dt.datetime.strptime(s, fmt).date()
        except ValueError:
            pass
    raise ValueError(f"Data inválida: {s!r}")

# %% [markdown]
# ### Perguntar de deseja utilizar arquivo baixado anteriormente
#
# Confirma com o usuário se um arquivo previamente baixado deve ser reutilizado. A função apresenta uma pergunta padronizada de sim/não, aplica um padrão por omissão e interpreta respostas comuns em português ou inglês.

# %%
def ask_yes_no(msg: str, default_yes=True) -> bool:
    prompt = " [S/n] " if default_yes else " [s/N] "
    while True:
        ans = input(msg + prompt).strip().lower()
        if not ans:
            return default_yes
        if ans in ("s","sim","y","yes"): return True
        if ans in ("n","nao","não","no"): return False
        print("Responda com s/n.")

# %% [markdown]
# ## Fluxo principal para preparação da base
#
# Orquestra toda a preparação da base, do input inicial ao salvamento final em parquet. O bloco coleta datas, verifica reaproveitamento de arquivos, dispara o download dos discursos e textos integrais e persiste o resultado consolidado.

# %%
ini, fim = ler_intervalo_datas()

out_path = DATA_DIR / f"discursos_{ini.isoformat()}_{fim.isoformat()}.parquet"
#out_path = DATA_DIR / f"discursos_{ini.isoformat()}_{fim.isoformat()}.csv"

if out_path.exists():
    if ask_yes_no(f"Arquivo já existe: {out_path}\nUsar o arquivo existente?"):
        log.info(f"Usando: {out_path}")
        df_final = pd.read_parquet(out_path)
        #df_final = pd.read_csv(out_path, sep=";", dtype=str)
        log.info(f"Discursos existentes no arquivo: {len(df_final)}")
        log.info(f"OK: {df_final['ok'].eq(True).sum()} textos baixados, {len(df_final)-df_final['ok'].eq(True).sum()} sem texto. Arquivo salvo em: {out_path}")
        #log.info(df_final["TextoDiscursoIntegral"].str.len())
        raise SystemExit(0)
    else:
        log.info("Refazendo download dos discursos…")

log.info(f"Recuperando lista de discursos realizados no período de {ini} a {fim}")
df_discursos = recuperar_lista_discursos_por_periodo(ini, fim, sleep_s=0.0)
log.info(f"Lista de discursos recuperados: {len(df_discursos)}")

log.info(f"Prepando discursos para download")
df_download = preparar_discursos_para_download(df_discursos)
log.info(f"Discursos com link para download do texto integral {len(df_download)}")

log.info(f"Iniciando download do texto integral do discurso com link para texto integral: {len(df_download)}")
df_txt = fazer_download_texto_discursos(df_download, recuperar_texto_discurso, max_workers=8)
log.info(f"Foi realizado o download dos textos de discursos: {len(df_txt)}")

df_final = df_discursos.merge(
    df_txt[["CodigoPronunciamento", "TextoDiscursoIntegral", "ok", "status", "msg"]],
    on="CodigoPronunciamento",
    how="left"
)

log.info(f"Textos no data frame final: {len(df_final)}")
log.info(f"Discursos por período: {len(df_discursos):,} linhas")

log.info(f"Salvando arquivo com a lista dos discursos e os respectivos textos integrais")
df_final.to_parquet(out_path, index=False, engine="pyarrow", compression="zstd")
#df_final.to_csv(
#    out_path,
#    index=False,
#    sep=";")
log.info(f"OK: {df_final['ok'].eq(True).sum()} textos baixados, {len(df_final)-df_final['ok'].eq(True).sum()} sem texto. Arquivo salvo em: {out_path}")

#log.info(df_final["TextoDiscursoIntegral"].str.len())
#log.info(df_final["TextoDiscursoIntegral"].str.split().str.len())
# Out:
# Informe o intervalo (ENTER para usar padrão 2019-03-29 → 2019-03-31).
# 2025-10-10 17:42:38,368 [INFO] Recuperando lista de discursos realizados no período de 2019-02-01 a 2023-01-31
# 2025-10-10 17:42:38,369 [INFO] >>> Preparando intervalos para download dos discursos de 2019-02-01 a 2023-01-31
# 2025-10-10 17:42:38,370 [INFO] >>> Montando intervalos de 31 dias para fazer download dos discursos em blocos
# 2025-10-10 17:42:38,370 [INFO] >>> >>> Janela 1: (datetime.date(2019, 2, 1), datetime.date(2019, 3, 3))
# 2025-10-10 17:42:38,371 [INFO] >>> >>> Janela 2: (datetime.date(2019, 3, 4), datetime.date(2019, 4, 3))
# 2025-10-10 17:42:38,372 [INFO] >>> >>> Janela 3: (datetime.date(2019, 4, 4), datetime.date(2019, 5, 4))
# 2025-10-10 17:42:38,373 [INFO] >>> >>> Janela 4: (datetime.date(2019, 5, 5), datetime.date(2019, 6, 4))
# 2025-10-10 17:42:38,373 [INFO] >>> >>> Janela 5: (datetime.date(2019, 6, 5), datetime.date(2019, 7, 5))
# 2025-10-10 17:42:38,374 [INFO] >>> >>> Janela 6: (datetime.date(2019, 7, 6), datetime.date(2019, 8, 5))
# 2025-10-10 17:42:38,375 [INFO] >>> >>> Janela 7: (datetime.date(2019, 8, 6), datetime.date(2019, 9, 5))
# 2025-10-10 17:42:38,375 [INFO] >>> >>> Janela 8: (datetime.date(2019, 9, 6), datetime.date(2019, 10, 6))
# 2025-10-10 17:42:38,376 [INFO] >>> >>> Janela 9: (datetime.date(2019, 10, 7), datetime.date(2019, 11, 6))
# 2025-10-10 17:42:38,377 [INFO] >>> >>> Janela 10: (datetime.date(2019, 11, 7), datetime.date(2019, 12, 7))
# 2025-10-10 17:42:38,378 [INFO] >>> >>> Janela 11: (datetime.date(2019, 12, 8), datetime.date(2020, 1, 7))
# 2025-10-10 17:42:38,378 [INFO] >>> >>> Janela 12: (datetime.date(2020, 1, 8), datetime.date(2020, 2, 7))
# 2025-10-10 17:42:38,379 [INFO] >>> >>> Janela 13: (datetime.date(2020, 2, 8), datetime.date(2020, 3, 9))
# 2025-10-10 17:42:38,379 [INFO] >>> >>> Janela 14: (datetime.date(2020, 3, 10), datetime.date(2020, 4, 9))
# 2025-10-10 17:42:38,380 [INFO] >>> >>> Janela 15: (datetime.date(2020, 4, 10), datetime.date(2020, 5, 10))
# 2025-10-10 17:42:38,381 [INFO] >>> >>> Janela 16: (datetime.date(2020, 5, 11), datetime.date(2020, 6, 10))
# 2025-10-10 17:42:38,382 [INFO] >>> >>> Janela 17: (datetime.date(2020, 6, 11), datetime.date(2020, 7, 11))
# 2025-10-10 17:42:38,383 [INFO] >>> >>> Janela 18: (datetime.date(2020, 7, 12), datetime.date(2020, 8, 11))
# 2025-10-10 17:42:38,384 [INFO] >>> >>> Janela 19: (datetime.date(2020, 8, 12), datetime.date(2020, 9, 11))
# 2025-10-10 17:42:38,384 [INFO] >>> >>> Janela 20: (datetime.date(2020, 9, 12), datetime.date(2020, 10, 12))
# 2025-10-10 17:42:38,385 [INFO] >>> >>> Janela 21: (datetime.date(2020, 10, 13), datetime.date(2020, 11, 12))
# 2025-10-10 17:42:38,386 [INFO] >>> >>> Janela 22: (datetime.date(2020, 11, 13), datetime.date(2020, 12, 13))
# 2025-10-10 17:42:38,387 [INFO] >>> >>> Janela 23: (datetime.date(2020, 12, 14), datetime.date(2021, 1, 13))
# 2025-10-10 17:42:38,387 [INFO] >>> >>> Janela 24: (datetime.date(2021, 1, 14), datetime.date(2021, 2, 13))
# 2025-10-10 17:42:38,388 [INFO] >>> >>> Janela 25: (datetime.date(2021, 2, 14), datetime.date(2021, 3, 16))
# 2025-10-10 17:42:38,389 [INFO] >>> >>> Janela 26: (datetime.date(2021, 3, 17), datetime.date(2021, 4, 16))
# 2025-10-10 17:42:38,390 [INFO] >>> >>> Janela 27: (datetime.date(2021, 4, 17), datetime.date(2021, 5, 17))
# 2025-10-10 17:42:38,391 [INFO] >>> >>> Janela 28: (datetime.date(2021, 5, 18), datetime.date(2021, 6, 17))
# 2025-10-10 17:42:38,391 [INFO] >>> >>> Janela 29: (datetime.date(2021, 6, 18), datetime.date(2021, 7, 18))
# 2025-10-10 17:42:38,392 [INFO] >>> >>> Janela 30: (datetime.date(2021, 7, 19), datetime.date(2021, 8, 18))
# 2025-10-10 17:42:38,393 [INFO] >>> >>> Janela 31: (datetime.date(2021, 8, 19), datetime.date(2021, 9, 18))
# 2025-10-10 17:42:38,394 [INFO] >>> >>> Janela 32: (datetime.date(2021, 9, 19), datetime.date(2021, 10, 19))
# 2025-10-10 17:42:38,394 [INFO] >>> >>> Janela 33: (datetime.date(2021, 10, 20), datetime.date(2021, 11, 19))
# 2025-10-10 17:42:38,395 [INFO] >>> >>> Janela 34: (datetime.date(2021, 11, 20), datetime.date(2021, 12, 20))
# 2025-10-10 17:42:38,396 [INFO] >>> >>> Janela 35: (datetime.date(2021, 12, 21), datetime.date(2022, 1, 20))
# 2025-10-10 17:42:38,397 [INFO] >>> >>> Janela 36: (datetime.date(2022, 1, 21), datetime.date(2022, 2, 20))
# 2025-10-10 17:42:38,397 [INFO] >>> >>> Janela 37: (datetime.date(2022, 2, 21), datetime.date(2022, 3, 23))
# 2025-10-10 17:42:38,398 [INFO] >>> >>> Janela 38: (datetime.date(2022, 3, 24), datetime.date(2022, 4, 23))
# 2025-10-10 17:42:38,398 [INFO] >>> >>> Janela 39: (datetime.date(2022, 4, 24), datetime.date(2022, 5, 24))
# 2025-10-10 17:42:38,399 [INFO] >>> >>> Janela 40: (datetime.date(2022, 5, 25), datetime.date(2022, 6, 24))
# 2025-10-10 17:42:38,400 [INFO] >>> >>> Janela 41: (datetime.date(2022, 6, 25), datetime.date(2022, 7, 25))
# 2025-10-10 17:42:38,400 [INFO] >>> >>> Janela 42: (datetime.date(2022, 7, 26), datetime.date(2022, 8, 25))
# 2025-10-10 17:42:38,401 [INFO] >>> >>> Janela 43: (datetime.date(2022, 8, 26), datetime.date(2022, 9, 25))
# 2025-10-10 17:42:38,402 [INFO] >>> >>> Janela 44: (datetime.date(2022, 9, 26), datetime.date(2022, 10, 26))
# 2025-10-10 17:42:38,402 [INFO] >>> >>> Janela 45: (datetime.date(2022, 10, 27), datetime.date(2022, 11, 26))
# 2025-10-10 17:42:38,403 [INFO] >>> >>> Janela 46: (datetime.date(2022, 11, 27), datetime.date(2022, 12, 27))
# 2025-10-10 17:42:38,404 [INFO] >>> >>> Janela 47: (datetime.date(2022, 12, 28), datetime.date(2023, 1, 27))
# 2025-10-10 17:42:38,405 [INFO] >>> >>> Janela 48: (datetime.date(2023, 1, 28), datetime.date(2023, 1, 31))
# 2025-10-10 17:42:38,406 [INFO] >>> O download dos discursos será realizado em 48 intervalos
# 2025-10-10 17:42:38,407 [INFO] >>> Iniciando download dos discursos em 48 intervalos
# 2025-10-10 17:42:38,409 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190201/20190303.json
# 2025-10-10 17:42:39,809 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:39,816 [INFO] >>> >>> Discursos extraídos: 1
# 2025-10-10 17:42:39,817 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190304/20190403.json
# 2025-10-10 17:42:40,430 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:40,437 [INFO] >>> >>> Discursos extraídos: 2
# 2025-10-10 17:42:40,438 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190404/20190504.json
# 2025-10-10 17:42:40,803 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:40,807 [INFO] >>> >>> Discursos extraídos: 3
# 2025-10-10 17:42:40,808 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190505/20190604.json
# 2025-10-10 17:42:41,413 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:41,420 [INFO] >>> >>> Discursos extraídos: 4
# 2025-10-10 17:42:41,421 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190605/20190705.json
# 2025-10-10 17:42:41,867 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:41,871 [INFO] >>> >>> Discursos extraídos: 5
# 2025-10-10 17:42:41,872 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190706/20190805.json
# 2025-10-10 17:42:42,182 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:42,186 [INFO] >>> >>> Discursos extraídos: 6
# 2025-10-10 17:42:42,187 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190806/20190905.json
# 2025-10-10 17:42:42,709 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:42,717 [INFO] >>> >>> Discursos extraídos: 7
# 2025-10-10 17:42:42,717 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20190906/20191006.json
# 2025-10-10 17:42:43,132 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:43,138 [INFO] >>> >>> Discursos extraídos: 8
# 2025-10-10 17:42:43,139 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191007/20191106.json
# 2025-10-10 17:42:43,613 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:43,618 [INFO] >>> >>> Discursos extraídos: 9
# 2025-10-10 17:42:43,618 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191107/20191207.json
# 2025-10-10 17:42:43,997 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:44,002 [INFO] >>> >>> Discursos extraídos: 10
# 2025-10-10 17:42:44,003 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20191208/20200107.json
# 2025-10-10 17:42:44,303 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:44,307 [INFO] >>> >>> Discursos extraídos: 11
# 2025-10-10 17:42:44,308 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200108/20200207.json
# 2025-10-10 17:42:44,620 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:44,622 [INFO] >>> >>> Discursos extraídos: 12
# 2025-10-10 17:42:44,623 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200208/20200309.json
# 2025-10-10 17:42:44,978 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:44,984 [INFO] >>> >>> Discursos extraídos: 13
# 2025-10-10 17:42:44,984 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200310/20200409.json
# 2025-10-10 17:42:45,374 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:45,377 [INFO] >>> >>> Discursos extraídos: 14
# 2025-10-10 17:42:45,378 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200410/20200510.json
# 2025-10-10 17:42:45,881 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:45,885 [INFO] >>> >>> Discursos extraídos: 15
# 2025-10-10 17:42:45,886 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200511/20200610.json
# 2025-10-10 17:42:46,151 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:46,154 [INFO] >>> >>> Discursos extraídos: 16
# 2025-10-10 17:42:46,155 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200611/20200711.json
# 2025-10-10 17:42:46,434 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:46,439 [INFO] >>> >>> Discursos extraídos: 17
# 2025-10-10 17:42:46,439 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200712/20200811.json
# 2025-10-10 17:42:46,760 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:46,762 [INFO] >>> >>> Discursos extraídos: 18
# 2025-10-10 17:42:46,763 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200812/20200911.json
# 2025-10-10 17:42:47,140 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:47,142 [INFO] >>> >>> Discursos extraídos: 19
# 2025-10-10 17:42:47,143 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20200912/20201012.json
# 2025-10-10 17:42:47,373 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:47,375 [INFO] >>> >>> Discursos extraídos: 20
# 2025-10-10 17:42:47,376 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201013/20201112.json
# 2025-10-10 17:42:47,604 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:47,609 [INFO] >>> >>> Discursos extraídos: 21
# 2025-10-10 17:42:47,612 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201113/20201213.json
# 2025-10-10 17:42:47,885 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:47,887 [INFO] >>> >>> Discursos extraídos: 22
# 2025-10-10 17:42:47,888 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20201214/20210113.json
# 2025-10-10 17:42:48,146 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:48,154 [INFO] >>> >>> Discursos extraídos: 23
# 2025-10-10 17:42:48,155 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210114/20210213.json
# 2025-10-10 17:42:48,411 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:48,418 [INFO] >>> >>> Discursos extraídos: 24
# 2025-10-10 17:42:48,418 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210214/20210316.json
# 2025-10-10 17:42:48,778 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:48,782 [INFO] >>> >>> Discursos extraídos: 25
# 2025-10-10 17:42:48,783 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210317/20210416.json
# 2025-10-10 17:42:49,296 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:49,301 [INFO] >>> >>> Discursos extraídos: 26
# 2025-10-10 17:42:49,301 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210417/20210517.json
# 2025-10-10 17:42:49,666 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:49,670 [INFO] >>> >>> Discursos extraídos: 27
# 2025-10-10 17:42:49,671 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210518/20210617.json
# 2025-10-10 17:42:50,232 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:50,239 [INFO] >>> >>> Discursos extraídos: 28
# 2025-10-10 17:42:50,240 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210618/20210718.json
# 2025-10-10 17:42:50,740 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:50,744 [INFO] >>> >>> Discursos extraídos: 29
# 2025-10-10 17:42:50,745 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210719/20210818.json
# 2025-10-10 17:42:51,345 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:51,353 [INFO] >>> >>> Discursos extraídos: 30
# 2025-10-10 17:42:51,353 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210819/20210918.json
# 2025-10-10 17:42:51,931 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:51,939 [INFO] >>> >>> Discursos extraídos: 31
# 2025-10-10 17:42:51,940 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20210919/20211019.json
# 2025-10-10 17:42:52,717 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:52,729 [INFO] >>> >>> Discursos extraídos: 32
# 2025-10-10 17:42:52,729 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211020/20211119.json
# 2025-10-10 17:42:53,319 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:53,327 [INFO] >>> >>> Discursos extraídos: 33
# 2025-10-10 17:42:53,328 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211120/20211220.json
# 2025-10-10 17:42:54,233 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:54,243 [INFO] >>> >>> Discursos extraídos: 34
# 2025-10-10 17:42:54,244 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20211221/20220120.json
# 2025-10-10 17:42:54,608 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:54,612 [INFO] >>> >>> Discursos extraídos: 35
# 2025-10-10 17:42:54,612 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220121/20220220.json
# 2025-10-10 17:42:55,143 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:55,150 [INFO] >>> >>> Discursos extraídos: 36
# 2025-10-10 17:42:55,150 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220221/20220323.json
# 2025-10-10 17:42:55,907 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:55,915 [INFO] >>> >>> Discursos extraídos: 37
# 2025-10-10 17:42:55,915 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220324/20220423.json
# 2025-10-10 17:42:56,390 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:56,396 [INFO] >>> >>> Discursos extraídos: 38
# 2025-10-10 17:42:56,397 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220424/20220524.json
# 2025-10-10 17:42:57,101 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:57,109 [INFO] >>> >>> Discursos extraídos: 39
# 2025-10-10 17:42:57,111 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220525/20220624.json
# 2025-10-10 17:42:57,820 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:57,830 [INFO] >>> >>> Discursos extraídos: 40
# 2025-10-10 17:42:57,830 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220625/20220725.json
# 2025-10-10 17:42:58,487 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:58,492 [INFO] >>> >>> Discursos extraídos: 41
# 2025-10-10 17:42:58,493 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220726/20220825.json
# 2025-10-10 17:42:58,820 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:58,824 [INFO] >>> >>> Discursos extraídos: 42
# 2025-10-10 17:42:58,825 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220826/20220925.json
# 2025-10-10 17:42:59,174 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:59,178 [INFO] >>> >>> Discursos extraídos: 43
# 2025-10-10 17:42:59,179 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20220926/20221026.json
# 2025-10-10 17:42:59,515 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:59,519 [INFO] >>> >>> Discursos extraídos: 44
# 2025-10-10 17:42:59,520 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221027/20221126.json
# 2025-10-10 17:42:59,822 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:42:59,826 [INFO] >>> >>> Discursos extraídos: 45
# 2025-10-10 17:42:59,826 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221127/20221227.json
# 2025-10-10 17:43:00,517 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:43:00,527 [INFO] >>> >>> Discursos extraídos: 46
# 2025-10-10 17:43:00,528 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20221228/20230127.json
# 2025-10-10 17:43:00,736 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:43:00,738 [INFO] >>> >>> Discursos extraídos: 47
# 2025-10-10 17:43:00,739 [INFO] >>> >>> GET: https://legis.senado.leg.br/dadosabertos/plenario/lista/discursos/20230128/20230131.json
# 2025-10-10 17:43:00,908 [INFO] >>> >>> Extraindo discurso
# 2025-10-10 17:43:01,052 [INFO] >>> Discursos recuperados: 15729
# 2025-10-10 17:43:01,056 [INFO] Lista de discursos recuperados: 15729
# 2025-10-10 17:43:01,058 [INFO] Prepando discursos para download
# 2025-10-10 17:43:01,117 [INFO] Discursos com link para download do texto integral 15729
# 2025-10-10 17:43:01,118 [INFO] Iniciando download do texto integral do discurso com link para texto integral: 15729
# 2025-10-10 17:43:01,119 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451286
# 2025-10-10 17:43:01,120 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451285
# 2025-10-10 17:43:01,121 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451205
# 2025-10-10 17:43:01,126 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451203
# 2025-10-10 17:43:01,128 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451202
# 2025-10-10 17:43:01,128 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451200
# 2025-10-10 17:43:01,128 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451195
# 2025-10-10 17:43:01,129 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451194
# 2025-10-10 17:43:01,324 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451193
# 2025-10-10 17:43:01,541 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451192
# 2025-10-10 17:43:01,752 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451190
# 2025-10-10 17:43:02,018 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451183
# 2025-10-10 17:43:02,098 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451181
# 2025-10-10 17:43:02,254 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451179
# 2025-10-10 17:43:02,256 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451177
# 2025-10-10 17:43:02,264 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451175
# 2025-10-10 17:43:02,387 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451173
# 2025-10-10 17:43:02,393 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451171
# 2025-10-10 17:43:02,403 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451167
# 2025-10-10 17:43:02,515 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451165
# 2025-10-10 17:43:02,568 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451163
# 2025-10-10 17:43:02,576 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451161
# 2025-10-10 17:43:02,597 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451159
# 2025-10-10 17:43:02,621 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451284
# 2025-10-10 17:43:02,641 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451283
# 2025-10-10 17:43:02,679 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451259
# 2025-10-10 17:43:02,707 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451257
# 2025-10-10 17:43:02,746 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451250
# 2025-10-10 17:43:02,763 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451237
# 2025-10-10 17:43:02,781 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451235
# 2025-10-10 17:43:02,813 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451230
# 2025-10-10 17:43:02,824 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451225
# 2025-10-10 17:43:02,828 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451212
# 2025-10-10 17:43:02,886 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451211
# 2025-10-10 17:43:02,922 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451210
# 2025-10-10 17:43:02,937 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451209
# 2025-10-10 17:43:02,939 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451208
# 2025-10-10 17:43:02,973 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451155
# 2025-10-10 17:43:02,993 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451153
# 2025-10-10 17:43:03,023 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451152
# 2025-10-10 17:43:03,058 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451151
# 2025-10-10 17:43:03,107 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451148
# 2025-10-10 17:43:03,110 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451147
# 2025-10-10 17:43:03,147 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451146
# 2025-10-10 17:43:03,160 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451120
# 2025-10-10 17:43:03,214 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451116
# 2025-10-10 17:43:03,228 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451112
# 2025-10-10 17:43:03,239 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451110
# 2025-10-10 17:43:03,323 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451108
# 2025-10-10 17:43:03,328 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451106
# 2025-10-10 17:43:03,342 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451143
# 2025-10-10 17:43:03,379 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451142
# 2025-10-10 17:43:03,383 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451141
# 2025-10-10 17:43:03,416 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451139
# 2025-10-10 17:43:03,422 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451138
# 2025-10-10 17:43:03,446 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451137
# 2025-10-10 17:43:03,520 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451136
# 2025-10-10 17:43:03,541 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451135
# 2025-10-10 17:43:03,571 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451134
# 2025-10-10 17:43:03,574 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451133
# 2025-10-10 17:43:03,610 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451131
# 2025-10-10 17:43:03,641 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451103
# 2025-10-10 17:43:03,645 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451101
# 2025-10-10 17:43:03,643 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451102
# 2025-10-10 17:43:03,699 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451100
# 2025-10-10 17:43:03,753 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451099
# 2025-10-10 17:43:03,759 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451084
# 2025-10-10 17:43:03,773 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451080
# 2025-10-10 17:43:03,795 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451066
# 2025-10-10 17:43:03,831 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451061
# 2025-10-10 17:43:03,909 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451060
# 2025-10-10 17:43:03,921 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451057
# 2025-10-10 17:43:03,955 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451056
# 2025-10-10 17:43:03,974 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451055
# 2025-10-10 17:43:03,978 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451054
# 2025-10-10 17:43:03,981 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451053
# 2025-10-10 17:43:03,990 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451052
# 2025-10-10 17:43:04,021 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451050
# 2025-10-10 17:43:04,136 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451049
# 2025-10-10 17:43:04,168 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451047
# 2025-10-10 17:43:04,178 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451046
# 2025-10-10 17:43:04,185 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451045
# 2025-10-10 17:43:04,187 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451043
# 2025-10-10 17:43:04,195 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451040
# 2025-10-10 17:43:04,204 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451037
# 2025-10-10 17:43:04,249 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451031
# 2025-10-10 17:43:04,390 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451011
# 2025-10-10 17:43:04,423 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451008
# 2025-10-10 17:43:04,428 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451006
# 2025-10-10 17:43:04,432 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450995
# 2025-10-10 17:43:04,434 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450994
# 2025-10-10 17:43:04,457 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450992
# 2025-10-10 17:43:04,469 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450989
# 2025-10-10 17:43:04,494 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450988
# 2025-10-10 17:43:04,575 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450987
# 2025-10-10 17:43:04,640 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450985
# 2025-10-10 17:43:04,643 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451123
# 2025-10-10 17:43:04,669 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/451122
# 2025-10-10 17:43:04,673 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450982
# 2025-10-10 17:43:04,692 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450976
# 2025-10-10 17:43:04,699 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450974
# 2025-10-10 17:43:04,770 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450972
# 2025-10-10 17:43:04,773 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450970
# 2025-10-10 17:43:04,832 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450968
# 2025-10-10 17:43:04,866 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450966
# 2025-10-10 17:43:04,889 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450964
# 2025-10-10 17:43:04,897 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450963
# 2025-10-10 17:43:04,941 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450941
# 2025-10-10 17:43:04,977 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450940
# 2025-10-10 17:43:04,980 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450939
# 2025-10-10 17:43:05,017 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450938
# 2025-10-10 17:43:05,051 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450937
# 2025-10-10 17:43:05,106 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450936
# 2025-10-10 17:43:05,153 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450934
# 2025-10-10 17:43:05,157 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450933
# 2025-10-10 17:43:05,196 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450958
# 2025-10-10 17:43:05,197 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450957
# 2025-10-10 17:43:05,235 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450956
# 2025-10-10 17:43:05,245 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450955
# 2025-10-10 17:43:05,324 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450954
# 2025-10-10 17:43:05,334 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450953
# 2025-10-10 17:43:05,382 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450952
# 2025-10-10 17:43:05,388 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450951
# 2025-10-10 17:43:05,402 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450950
# 2025-10-10 17:43:05,413 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450949
# 2025-10-10 17:43:05,436 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450948
# 2025-10-10 17:43:05,453 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450946
# 2025-10-10 17:43:05,506 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450945
# 2025-10-10 17:43:05,558 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450944
# 2025-10-10 17:43:05,578 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450962
# 2025-10-10 17:43:05,625 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450854
# 2025-10-10 17:43:05,654 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450850
# 2025-10-10 17:43:05,659 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450846
# 2025-10-10 17:43:05,688 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450842
# 2025-10-10 17:43:05,720 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450838
# 2025-10-10 17:43:05,730 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450836
# 2025-10-10 17:43:05,758 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450832
# 2025-10-10 17:43:05,771 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450830
# 2025-10-10 17:43:05,819 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450826
# 2025-10-10 17:43:05,890 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450822
# 2025-10-10 17:43:05,956 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450820
# 2025-10-10 17:43:05,959 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450818
# 2025-10-10 17:43:05,974 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450816
# 2025-10-10 17:43:05,990 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450814
# 2025-10-10 17:43:05,996 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450961
# 2025-10-10 17:43:06,034 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450930
# 2025-10-10 17:43:06,071 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450929
# 2025-10-10 17:43:06,102 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450928
# 2025-10-10 17:43:06,154 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450926
# 2025-10-10 17:43:06,188 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450925
# 2025-10-10 17:43:06,219 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450923
# 2025-10-10 17:43:06,222 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450922
# 2025-10-10 17:43:06,230 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450775
# 2025-10-10 17:43:06,235 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450768
# 2025-10-10 17:43:06,296 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450766
# 2025-10-10 17:43:06,307 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450764
# 2025-10-10 17:43:06,343 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450762
# 2025-10-10 17:43:06,401 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450760
# 2025-10-10 17:43:06,419 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450758
# 2025-10-10 17:43:06,432 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450757
# 2025-10-10 17:43:06,435 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450755
# 2025-10-10 17:43:06,472 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450753
# 2025-10-10 17:43:06,505 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450751
# 2025-10-10 17:43:06,562 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450750
# 2025-10-10 17:43:06,606 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450749
# 2025-10-10 17:43:06,641 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450748
# 2025-10-10 17:43:06,752 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450746
# 2025-10-10 17:43:06,800 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450740
# 2025-10-10 17:43:06,841 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450737
# 2025-10-10 17:43:07,035 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450736
# 2025-10-10 17:43:07,050 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450735
# 2025-10-10 17:43:07,183 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450960
# 2025-10-10 17:43:07,287 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450696
# 2025-10-10 17:43:07,330 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450694
# 2025-10-10 17:43:07,376 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450690
# 2025-10-10 17:43:07,467 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450686
# 2025-10-10 17:43:07,541 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450685
# 2025-10-10 17:43:07,670 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450684
# 2025-10-10 17:43:07,765 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450682
# 2025-10-10 17:43:07,816 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450680
# 2025-10-10 17:43:07,873 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450678
# 2025-10-10 17:43:07,959 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450676
# 2025-10-10 17:43:08,010 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450674
# 2025-10-10 17:43:08,076 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450672
# 2025-10-10 17:43:08,153 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450732
# 2025-10-10 17:43:08,318 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450731
# 2025-10-10 17:43:08,422 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450730
# 2025-10-10 17:43:08,511 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450728
# 2025-10-10 17:43:08,725 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450726
# 2025-10-10 17:43:08,728 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450724
# 2025-10-10 17:43:08,918 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450722
# 2025-10-10 17:43:08,932 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450720
# 2025-10-10 17:43:09,103 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450718
# 2025-10-10 17:43:09,194 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450716
# 2025-10-10 17:43:09,374 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450714
# 2025-10-10 17:43:09,377 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450712
# 2025-10-10 17:43:09,552 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450710
# 2025-10-10 17:43:09,591 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450708
# 2025-10-10 17:43:09,722 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450706
# 2025-10-10 17:43:09,769 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450704
# 2025-10-10 17:43:09,900 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450702
# 2025-10-10 17:43:09,950 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450700
# 2025-10-10 17:43:10,080 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450698
# 2025-10-10 17:43:10,131 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450660
# 2025-10-10 17:43:10,259 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450641
# 2025-10-10 17:43:10,347 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450636
# 2025-10-10 17:43:10,447 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450635
# 2025-10-10 17:43:10,538 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450634
# 2025-10-10 17:43:10,627 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450633
# 2025-10-10 17:43:10,725 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450631
# 2025-10-10 17:43:10,814 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450629
# 2025-10-10 17:43:10,913 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450619
# 2025-10-10 17:43:11,001 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450618
# 2025-10-10 17:43:11,100 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450617
# 2025-10-10 17:43:11,182 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450616
# 2025-10-10 17:43:11,294 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450615
# 2025-10-10 17:43:11,358 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450613
# 2025-10-10 17:43:11,484 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450612
# 2025-10-10 17:43:11,536 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450611
# 2025-10-10 17:43:11,661 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450610
# 2025-10-10 17:43:11,720 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450609
# 2025-10-10 17:43:11,836 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450607
# 2025-10-10 17:43:11,893 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450606
# 2025-10-10 17:43:12,022 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450605
# 2025-10-10 17:43:12,094 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450604
# 2025-10-10 17:43:12,207 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450603
# 2025-10-10 17:43:12,317 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450601
# 2025-10-10 17:43:12,387 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450600
# 2025-10-10 17:43:12,501 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450599
# 2025-10-10 17:43:12,594 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450598
# 2025-10-10 17:43:12,685 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450574
# 2025-10-10 17:43:12,768 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450533
# 2025-10-10 17:43:12,859 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450526
# 2025-10-10 17:43:12,941 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450524
# 2025-10-10 17:43:13,117 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450523
# 2025-10-10 17:43:13,218 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450514
# 2025-10-10 17:43:13,395 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450513
# 2025-10-10 17:43:13,448 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450512
# 2025-10-10 17:43:13,587 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450511
# 2025-10-10 17:43:13,775 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450510
# 2025-10-10 17:43:13,812 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450509
# 2025-10-10 17:43:14,003 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450508
# 2025-10-10 17:43:14,065 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450506
# 2025-10-10 17:43:14,195 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450504
# 2025-10-10 17:43:14,289 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450503
# 2025-10-10 17:43:14,419 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450497
# 2025-10-10 17:43:14,478 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450491
# 2025-10-10 17:43:14,651 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450486
# 2025-10-10 17:43:14,682 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450483
# 2025-10-10 17:43:14,838 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450482
# 2025-10-10 17:43:14,857 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450481
# 2025-10-10 17:43:15,011 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450480
# 2025-10-10 17:43:15,097 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450476
# 2025-10-10 17:43:15,278 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450474
# 2025-10-10 17:43:15,357 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450439
# 2025-10-10 17:43:15,455 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450408
# 2025-10-10 17:43:15,548 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450399
# 2025-10-10 17:43:15,633 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450398
# 2025-10-10 17:43:15,719 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450397
# 2025-10-10 17:43:15,973 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450396
# 2025-10-10 17:43:16,040 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450395
# 2025-10-10 17:43:16,145 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450394
# 2025-10-10 17:43:16,237 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450392
# 2025-10-10 17:43:16,376 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450391
# 2025-10-10 17:43:16,444 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/450390
# ...
# 2025-10-10 17:57:56,296 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494476
# 2025-10-10 17:57:56,358 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494475
# 2025-10-10 17:57:56,362 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494474
# 2025-10-10 17:57:56,376 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494472
# 2025-10-10 17:57:56,381 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494471
# 2025-10-10 17:57:56,448 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494470
# 2025-10-10 17:57:56,465 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494469
# 2025-10-10 17:57:56,496 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494468
# 2025-10-10 17:57:56,533 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494466
# 2025-10-10 17:57:56,571 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494465
# 2025-10-10 17:57:56,619 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494464
# 2025-10-10 17:57:56,619 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494512
# 2025-10-10 17:57:56,635 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494511
# 2025-10-10 17:57:56,650 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494510
# 2025-10-10 17:57:56,670 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494509
# 2025-10-10 17:57:56,700 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494508
# 2025-10-10 17:57:56,724 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494507
# 2025-10-10 17:57:56,787 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494506
# 2025-10-10 17:57:56,818 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494505
# 2025-10-10 17:57:56,880 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494504
# 2025-10-10 17:57:56,883 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494503
# 2025-10-10 17:57:56,886 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494460
# 2025-10-10 17:57:56,889 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494458
# 2025-10-10 17:57:56,897 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494456
# 2025-10-10 17:57:56,905 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494454
# 2025-10-10 17:57:56,968 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494453
# 2025-10-10 17:57:57,005 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494452
# 2025-10-10 17:57:57,065 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494450
# 2025-10-10 17:57:57,070 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494449
# 2025-10-10 17:57:57,096 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494448
# 2025-10-10 17:57:57,101 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494446
# 2025-10-10 17:57:57,148 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494444
# 2025-10-10 17:57:57,174 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494442
# 2025-10-10 17:57:57,188 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494440
# 2025-10-10 17:57:57,200 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494439
# 2025-10-10 17:57:57,243 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494438
# 2025-10-10 17:57:57,293 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494436
# 2025-10-10 17:57:57,303 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494435
# 2025-10-10 17:57:57,342 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494434
# 2025-10-10 17:57:57,357 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494433
# 2025-10-10 17:57:57,398 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494432
# 2025-10-10 17:57:57,413 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494431
# 2025-10-10 17:57:57,438 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494430
# 2025-10-10 17:57:57,487 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494429
# 2025-10-10 17:57:57,516 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494428
# 2025-10-10 17:57:57,542 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494427
# 2025-10-10 17:57:57,545 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494426
# 2025-10-10 17:57:57,572 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494425
# 2025-10-10 17:57:57,593 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494424
# 2025-10-10 17:57:57,611 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494423
# 2025-10-10 17:57:57,680 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494421
# 2025-10-10 17:57:57,691 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494418
# 2025-10-10 17:57:57,744 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494417
# 2025-10-10 17:57:57,745 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494416
# 2025-10-10 17:57:57,749 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494415
# 2025-10-10 17:57:57,776 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494414
# 2025-10-10 17:57:57,793 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494413
# 2025-10-10 17:57:57,866 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494412
# 2025-10-10 17:57:57,930 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494410
# 2025-10-10 17:57:57,942 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494409
# 2025-10-10 17:57:57,945 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494408
# 2025-10-10 17:57:57,946 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494407
# 2025-10-10 17:57:57,969 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494385
# 2025-10-10 17:57:58,006 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494384
# 2025-10-10 17:57:58,011 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494382
# 2025-10-10 17:57:58,039 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494381
# 2025-10-10 17:57:58,124 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494379
# 2025-10-10 17:57:58,125 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494377
# 2025-10-10 17:57:58,130 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494375
# 2025-10-10 17:57:58,167 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494373
# 2025-10-10 17:57:58,173 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494371
# 2025-10-10 17:57:58,196 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494369
# 2025-10-10 17:57:58,249 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494367
# 2025-10-10 17:57:58,277 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494366
# 2025-10-10 17:57:58,303 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494365
# 2025-10-10 17:57:58,347 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494363
# 2025-10-10 17:57:58,369 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494360
# 2025-10-10 17:57:58,390 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494358
# 2025-10-10 17:57:58,414 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494356
# 2025-10-10 17:57:58,421 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494355
# 2025-10-10 17:57:58,471 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494354
# 2025-10-10 17:57:58,473 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494350
# 2025-10-10 17:57:58,516 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494349
# 2025-10-10 17:57:58,559 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494348
# 2025-10-10 17:57:58,576 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494347
# 2025-10-10 17:57:58,588 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494346
# 2025-10-10 17:57:58,591 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494344
# 2025-10-10 17:57:58,596 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494342
# 2025-10-10 17:57:58,671 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494339
# 2025-10-10 17:57:58,672 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494337
# 2025-10-10 17:57:58,694 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494335
# 2025-10-10 17:57:58,757 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494333
# 2025-10-10 17:57:58,764 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494332
# 2025-10-10 17:57:58,778 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494331
# 2025-10-10 17:57:58,801 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/494329
# 2025-10-10 17:57:58,852 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495362
# 2025-10-10 17:57:58,879 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495361
# 2025-10-10 17:57:58,903 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495359
# 2025-10-10 17:57:58,951 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495357
# 2025-10-10 17:57:58,977 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495355
# 2025-10-10 17:57:58,979 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495353
# 2025-10-10 17:57:59,019 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495351
# 2025-10-10 17:57:59,050 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495349
# 2025-10-10 17:57:59,102 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495348
# 2025-10-10 17:57:59,103 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495502
# 2025-10-10 17:57:59,127 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495501
# 2025-10-10 17:57:59,139 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495500
# 2025-10-10 17:57:59,183 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495499
# 2025-10-10 17:57:59,187 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495498
# 2025-10-10 17:57:59,216 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495497
# 2025-10-10 17:57:59,234 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495496
# 2025-10-10 17:57:59,315 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495494
# 2025-10-10 17:57:59,323 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495493
# 2025-10-10 17:57:59,369 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495491
# 2025-10-10 17:57:59,380 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495490
# 2025-10-10 17:57:59,417 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495489
# 2025-10-10 17:57:59,540 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495488
# 2025-10-10 17:57:59,581 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495487
# 2025-10-10 17:57:59,617 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495486
# 2025-10-10 17:57:59,638 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495485
# 2025-10-10 17:57:59,749 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495484
# 2025-10-10 17:57:59,777 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495483
# 2025-10-10 17:57:59,820 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495482
# 2025-10-10 17:57:59,859 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495481
# 2025-10-10 17:57:59,934 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495480
# 2025-10-10 17:57:59,958 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495479
# 2025-10-10 17:57:59,992 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495478
# 2025-10-10 17:58:00,030 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495477
# 2025-10-10 17:58:00,113 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495476
# 2025-10-10 17:58:00,145 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495475
# 2025-10-10 17:58:00,162 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495474
# 2025-10-10 17:58:00,206 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495473
# 2025-10-10 17:58:00,284 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495471
# 2025-10-10 17:58:00,332 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495469
# 2025-10-10 17:58:00,351 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495467
# 2025-10-10 17:58:00,377 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495466
# 2025-10-10 17:58:00,458 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495465
# 2025-10-10 17:58:00,549 [INFO] >>> GET: https://legis.senado.leg.br/dadosabertos/discurso/texto-integral/495464
# 2025-10-10 17:58:15,914 [INFO] Foi realizado o download dos textos de discursos: 15729
# 2025-10-10 17:58:15,943 [INFO] Textos no data frame final: 15729
# 2025-10-10 17:58:15,944 [INFO] Discursos por período: 15,729 linhas
# 2025-10-10 17:58:15,945 [INFO] Salvando arquivo com a lista dos discursos e os respectivos textos integrais
# 2025-10-10 17:58:17,466 [INFO] OK: 15039 textos baixados, 690 sem texto. Arquivo salvo em: _data/discursos_2019-02-01_2023-01-31.parquet

# %% [markdown]
# ## Converter para csv

# %%
log.info("Salvando versão em CSV com tratamento de aspas e caracteres especiais")
csv_path = out_path.with_suffix('.csv')

df_final_csv = df_final.copy()
object_cols = df_final_csv.select_dtypes(include=['object']).columns
if len(object_cols) > 0:
    df_final_csv[object_cols] = df_final_csv[object_cols].replace({r'\r\n?': '\n'}, regex=True)

df_final_csv.to_csv(
    csv_path,
    index=False,
    sep=';',
    quoting=csv.QUOTE_ALL,
    escapechar='\\',
    #line_terminator='\n',
    encoding='utf-8'
)
log.info(f"Arquivo CSV salvo em: {csv_path}")
# Out:
# 2025-10-10 18:20:27,630 [INFO] Salvando versão em CSV com tratamento de aspas e caracteres especiais
# 2025-10-10 18:20:31,497 [INFO] Arquivo CSV salvo em: _data/discursos_2019-02-01_2023-01-31.csv
