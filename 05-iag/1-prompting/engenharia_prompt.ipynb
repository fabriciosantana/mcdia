# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriciosantana/mcdia/blob/main/05-iag/engenharia_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Engenharia de Prompt

# %% [markdown]
# ## 1. Conexão com o modelo

# %%
# Libs

#from google.colab import userdata
from huggingface_hub import login
from huggingface_hub import InferenceClient
from IPython.display import Markdown, display
import os
from dotenv import load_dotenv

# %%
# Login Hugging Face e conexão com modelo

#API_KEY = userdata.get('HF_TOKEN')
load_dotenv()
API_KEY = os.environ.get('HF_TOKEN')

#login(API_KEY)

MODEL = "meta-llama/Meta-Llama-3-8B-Instruct"
client = InferenceClient(
    model=MODEL,
    token=API_KEY
)

# %% [markdown]
# ## 2. Funções auxiliares

# %%
# Função de geração de texto

def printmd(string):
    display(Markdown(string))

def chat_generate(
    messages,
    temperature=0.2,
    top_p=0.95,
    max_tokens=500
):
    response = client.chat.completions.create(
        messages=messages,
        temperature=temperature,
        top_p=top_p,
        max_tokens=max_tokens,
    )

    return response.choices[0].message.content

# %% [markdown]
# ## 3. Configurações de Amostragem

# %%
prompt1 = [
    {
        "role": "user",
        "content": """Aqui estão as notas brutas de um fiscal sobre o 'Festival
        de Inverno' na Praça da Matriz: [Notas: Público estimado de 2.000
        pessoas; som ultrapassou 80 decibéis após as 22h; 5 barracas de comida
        sem alvará sanitário; presença massiva de famílias; decorações feitas
        por artesãos locais; nenhum incidente de segurança grave registrado].

        Tarefa: Com base nessas notas, escreva um texto de um parágrafo sobre
        o evento."""
    }
]

# %% [markdown]
# ### 3.1. Cenário 1: Coerente e formal (mais estabilidade)

# %%
temperatura = 0.0
top_p = 0.1

for i in range(3):
  printmd(f"\n## RESPOSTA {i+1}:\n")
  printmd(chat_generate(
      prompt1,
      temperature = temperatura,
      top_p = top_p
    )
  )
# Out:
# ## RESPOSTA 1:
# O Festival de Inverno na Praça da Matriz foi um sucesso de público, com uma estimativa de 2.000 pessoas presentes. Embora o som tenha ultrapassado os 80 decibéis após as 22h, o evento foi marcado por uma atmosfera alegre e familiar, com a presença massiva de famílias. Além disso, as decorações foram feitas por artesãos locais, adicionando um toque autêntico ao evento. No entanto, foi observado que 5 barracas de comida não tinham alvará sanitário, o que é um problema que deve ser abordado. Felizmente, não houve incidentes de segurança graves registrados, o que é um bom sinal para o sucesso do evento.
# ## RESPOSTA 2:
# O Festival de Inverno na Praça da Matriz foi um sucesso de público, com cerca de 2.000 pessoas presentes. Embora o som tenha ultrapassado os 80 decibéis após as 22h, o evento foi marcado por uma atmosfera alegre e familiar, com a presença massiva de famílias. Além disso, as decorações foram criadas por artesãos locais, adicionando um toque autêntico ao evento. No entanto, foi observado que 5 barracas de comida não tinham alvará sanitário, o que é um problema de saúde pública que precisa ser abordado. Apesar disso, o evento foi considerado seguro, sem incidentes graves registrados.
# ## RESPOSTA 3:
# O Festival de Inverno na Praça da Matriz foi um sucesso de público, com uma estimativa de 2.000 pessoas presentes. Embora o som tenha ultrapassado os 80 decibéis após as 22h, o evento foi marcado por uma atmosfera alegre e familiar, com a presença massiva de famílias. Além disso, as decorações foram feitas por artesãos locais, adicionando um toque autêntico ao evento. No entanto, foi observado que 5 barracas de comida não tinham alvará sanitário, o que é um problema de saúde pública que precisa ser abordado. Apesar disso, o evento foi considerado seguro, sem incidentes graves registrados.

# %% [markdown]
# ### 3.2. Cenário 2: Criativo (mais diversidade)

# %%
temperatura = 1.0
top_p = 1.0

for i in range(3):
  printmd(f"\n## RESPOSTA {i+1}:\n")
  printmd(chat_generate(
      prompt1,
      temperature = temperatura,
      top_p = top_p
    )
  )
# Out:
# ## RESPOSTA 1:
# O "Festival de Inverno" na Praça da Matriz foi um sucesso de público e experiência, apesar de alguns pequenos problemas. Com uma multidão estimada de 2.000 pessoas, o evento teve a presença massiva de famílias, o que sugere uma atmosfera alegre e acolhedora. É digno de nota a contribuição local, uma vez que a decoração foi realizada por artesãos locais. No entanto, é importante lembrar que houve alguns equívocos, como a falta de alvará sanitário em 5 barracas de comida, e o excesso de barulho, uma vez que os áudios ultrapassaram 80 decibéis após as 22h. Infelizmente, foi preciso registrar essas falhas para entender melhor e garantir o controle adequado nestes tipos de eventos.
# ## RESPOSTA 2:
# O Festival de Inverno na Praça da Matriz foi um sucesso agradável graças à grande presença de famílias, quelotas apreciadoras ao som que durante a noite, entretanto, ultrapassou o limite permitido de 80 decibéis. Embora as atrações tenham sido bem recebidas, é preocupante que a festa tenha violado as regulamentações de som. Por outro lado, o evento também destacou a espirito cartesanal locais, que se mostraram apaixonados na criação de decorações simples porém do jeito.  Além disso, a comida, oferecida em 5 barracas, esmerou-se por todos canais nem tempo em ponderar a 'viabilidade jurídica' de pedido-a sem banho de segurança, muitas artistas locais disfrutaram agogo revertia e ensinavam aos jovems revelações música, associando-se mundo estonteante geral que não gerou paralis atrapalhando festa.
# ## RESPOSTA 3:
# O 'Festival de Inverno' na Praça da Matriz foi um sucesso entre os 2.000 espectadores presentes, com um ambiente animado por famílias. No entanto, alguns problemas foram registrados, como o som ultrapassar os 80 decibéis após as 22h, e a presença de 5 barracas de comida sem alvará sanitário, o que pode ser considerado uma irregularidade. Apesar disso, as decorações feitas por artesãos locais foram destaque, criando um ambiente aconchegante e acolhedor. Finalmente, não houve incidentes graves de segurança, o que é uma boa notícia, e evidencia a organização do evento.

# %% [markdown]
# ## 4. Arquitetura de Prompt

# %% [markdown]
# ### 4.1. Cenário 1 (Fiscalização)

# %%
# System Prompt (Propósito e Formato)
system_prompt2 = '''
PROPÓSITO E FORMATO: Você é um sistema especializado em processamento de dados
administrativos e conformidade regulatória. Sua função é transformar anotações
de campo desestruturadas em relatórios técnicos precisos, garantindo que nenhum
dado factual seja omitido ou alterado. *Sua saída deve ser estritamente em
formato JSON válido*. Não inclua informações fora do JSON.

*Esquema JSON obrigatório:*

{
  "evento": string,
  "publico_alvo": string,
  "volume_estimado": int,
  "infracoes_detectadas": [
    {
      "tipo": string,
      "descricao": string,
      "risco_regulatorio": string
    }
  ],
  "balanco_seguranca": string
}
'''

# Role Prompt (Persona e Tom):
role_prompt2 = '''
PERSONA: Aja como um *Auditor de Serviços Públicos sênior*. Adote um tom
formal, imparcial e analítico. Sua expertise deve focar em identificar riscos
sanitários, conformidade sonora e segurança pública, priorizando a clareza
quanto ao impacto regulatório.
'''

# Contextual Prompt (Dados Variáveis)
context_prompt2 = '''
CONTEXTO: Fiscalização realizada no 'Festival de Inverno' na Praça da Matriz.

NOTAS BRUTAS: {Público estimado de 2.000 pessoas; som ultrapassou 80 decibéis
após as 22h; 5 barracas de comida sem alvará sanitário; presença massiva de
famílias; decorações feitas por artesãos locais; nenhum incidente de segurança
grave registrado}.
'''

# Tarefa e instruções
task_instructions2 = '''
TAREFA: *Analise* as notas acima e *gere* um resumo técnico estruturado em JSON.

*INSTRUÇÕES:* Liste as métricas de público, categorize as infrações por tipo
(sanitária/sonora) e descreva o impacto social positivo observado.
'''

# %%
prompt2 = [
    {
        "role": "system",
        "content": f"""
{system_prompt2}

{role_prompt2}

"""
    },
    {
        "role": "user",
        "content": f"""
{context_prompt2}

{task_instructions2}

Agora execute a tarefa.
"""
    }
]

# %%
temperatura = 0.1
top_p = 0.9

for i in range(2):
  printmd(f"\n## RESPOSTA {i+1}:\n")
  printmd(chat_generate(
      prompt2,
      temperature = temperatura,
      top_p = top_p
    )
  )
# Out:
# ## RESPOSTA 1:
# **Resumo Técnico do Fiscalização do Festival de Inverno**
#
# ```json
# {
#   "evento": "Festival de Inverno",
#   "publico_alvo": "Praça da Matriz",
#   "volume_estimado": 2000,
#   "infracoes_detectadas": [
#     {
#       "tipo": "sanitária",
#       "descricao": "5 barracas de comida sem alvará sanitário",
#       "risco_regulatorio": "Risco de contaminação alimentar"
#     },
#     {
#       "tipo": "sonora",
#       "descricao": "Som ultrapassou 80 decibéis após as 22h",
#       "risco_regulatorio": "Risco de danos auditivos"
#     }
#   ],
#   "balanco_seguranca": "Nenhum incidente de segurança grave registrado"
# }
# ```
#
# **Análise e Observações**
#
# * O público estimado foi de 2.000 pessoas, o que indica uma grande concentração de pessoas na área.
# * Foram detectadas 2 infrações, sendo 1 sanitária e 1 sonora.
#  * A infração sanitária foi a presença de 5 barracas de comida sem alvará sanitário, o que representa um risco de contaminação alimentar.
#  * A infração sonora foi o som ultrapassar 80 decibéis após as 22h, o que representa um risco de danos auditivos.
# * O festival contou com a presença massiva de famílias, o que indica um impacto social positivo.
# * As decorações foram feitas por artesãos locais, o que contribui para a economia local e a preservação da cultura local.
# * Nenhum incidente de segurança grave foi registrado, o que indica que as medidas de segurança foram eficazes.
# ## RESPOSTA 2:
# **Resumo Técnico do Fiscalização do Festival de Inverno**
#
# ```json
# {
#   "evento": "Festival de Inverno",
#   "publico_alvo": "Praça da Matriz",
#   "volume_estimado": 2000,
#   "infracoes_detectadas": [
#     {
#       "tipo": "sanitária",
#       "descricao": "5 barracas de comida sem alvará sanitário",
#       "risco_regulatorio": "Risco de contaminação alimentar"
#     },
#     {
#       "tipo": "sonora",
#       "descricao": "Som ultrapassou 80 decibéis após as 22h",
#       "risco_regulatorio": "Risco de danos auditivos"
#     }
#   ],
#   "balanco_seguranca": "Nenhum incidente de segurança grave registrado"
# }
# ```
#
# **Análise e Observações**
#
# - O público estimado foi de 2.000 pessoas, o que indica uma grande concentração de pessoas na área.
# - Foram detectadas 2 infrações: 1 sanitária e 1 sonora.
# - A infração sanitária foi causada pela presença de 5 barracas de comida sem alvará sanitário, o que pode representar um risco de contaminação alimentar.
# - A infração sonora foi causada pelo som ultrapassar 80 decibéis após as 22h, o que pode representar um risco de danos auditivos.
# - O balanço de segurança foi positivo, com nenhum incidente de segurança grave registrado.
# - O festival também teve um impacto social positivo, com a presença massiva de famílias e a decoração feita por artesãos locais, o que pode ter contribuído para a sensação de comunidade e alegria.

# %% [markdown]
# ### 4.2. Cenário 2 (Marketing Institucional)

# %%
# System Prompt (Propósito e Formato)
system_prompt3 = '''
PROPÓSITO E FORMATO: Você é um especialista em *Comunicação Social e Marketing
Governamental*. Sua função é transformar dados brutos de fiscalização em
eventos em *narrativas institucionais inspiradoras* que valorizem a imagem da
prefeitura e o bem-estar da comunidade. Você deve garantir que a saída seja
rica em detalhes, mas extremamente concisa. *Sua saída deve ser estritamente em
formato JSON válido* para  ser consumida por plataformas de redes sociais e
sites oficiais. Não inclua explicações fora do JSON.

*Esquema JSON obrigatório:*
{
  "manchete_impacto": string,
  "corpo_texto_denso": string,
  "destaque_comunitario": string,
  "hashtags_sugeridas": string
}
'''

# Role Prompt (Persona e Tom):
role_prompt3 = '''
PERSONA: Aja como um *Redator Publicitário Criativo*. Adote um tom *Inspirador,
Persuasivo e Influente*. Sua expertise deve focar em destacar o sucesso do
evento, a segurança das famílias e o apoio à economia local, transformando
números em conquistas sociais.
'''

# Contextual Prompt (Dados Variáveis)
context_prompt3 = '''
CONTEXTO: Fiscalização realizada no 'Festival de Inverno' na Praça da Matriz.

NOTAS BRUTAS: {Público estimado de 2.000 pessoas; som ultrapassou 80 decibéis
após as 22h; 5 barracas de comida sem alvará sanitário; presença massiva de
famílias; decorações feitas por artesãos locais; nenhum incidente de segurança
grave registrado}.
'''

# Tarefa e instruções
task_instructions3 = '''
TAREFA: Crie uma síntese narrativa do evento.

INSTRUÇÕES: Foque na harmonia e no sucesso do evento; Use verbos de ação como
'Celebrar', 'Fortalecer' e 'Encantar'.
'''

# %%
prompt3 = [
    {
        "role": "system",
        "content": f"""
{system_prompt3}

{role_prompt3}

"""
    },
    {
        "role": "user",
        "content": f"""
{context_prompt3}

{task_instructions3}

Agora execute a tarefa.
"""
    }
]

# %%
temperatura = 0.9
top_p = 0.99

for i in range(2):
  printmd(f"\n## RESPOSTA {i+1}:\n")
  printmd(chat_generate(
      prompt3,
      temperature = temperatura,
      top_p = top_p
    )
  )
# Out:
# ## RESPOSTA 1:
# {
#   "manchete_impacto": "Festival de Inverno: Celebração de Harmonia e Satisfação",
#   "corpo_texto_denso": "Milhares de pessoas se reuniram na Praça da Matriz para celebrar o Festival de Inverno, um evento que fortaleceu a conexão comunitária e encantou a cidade com decorações criadas por artesãos locais. Ao mesmo tempo, a presença massiva de famílias reafirmou a importância do festival como um espaço seguro e alegre para todos. É com alegria que podemos registrar um total de 2.000 visitantes, sem incidentes de segurança graves. Um sucesso realce para os organizadores e um presente para a nossa comunidade.",
#   "destaque_comunitario": "Com a fé em uma cidade que se reúne e se fortalece através das celebrações, estamos determinados a dar continuidade a essas histórias de encantamento da Praça da Matriz. Nossa gratidão aos participantes, organizadores e todos os envolvidos na criação desse momento único!",
#   "hashtags_sugeridas": "#FestivalDeInverno #CelebrarHarmonia #PraçaDaMatriz #ComunidadeUnida #Sucesso #ArtisanatoLocal #LugaresSeguros #FestasEncantadoras"
# }
# ## RESPOSTA 2:
# {
#   "manchete_impacto": "Festival de Inverno Celebra Harmonia e Alegria Pelo Centro",
#   "corpo_texto_denso": "Cento e oitenta decibéis de energia e coração: assim foi o Festival de Inverno que encantou mais de 2.000 pessoas que compareceram à Praça da Matriz. Desse dia histórico, saíram conquistas sociais: 5 barracas de comida locais foram fortalecidas, demonstrando a força do empreendedorismo local. O som vibrante, apesar de algumas desafios por volta da meia-noite, não acabou com a magia. Sem incidentes graves, as famílias puderam celebrar o inverno de forma segura e inesquecível. Tudo com um toque de glamour: as decorações, criadas por habilidosos artesãos da nossa terra, encantaram todos os que compareceram a esse espetáculo de luz, som e cor. ",
#   "destaque_comunitario": "Famílias se conectam, criam memórias e fortalecem a comunidade em um dia de muita alegria e diversão!",
#   "hashtags_sugeridas": "#FestivalDeInverno #PraçaDaMatriz #ComunidadeFortalecida #MúsicaEArte #EmpreendedorismoLocal"
# }

# %% [markdown]
# ## 5. Zero-shot, One-shot e Few-shot Prompting

# %% [markdown]
# Incremente o prompt com persona "Auditor de serviços públicos sênior" (zero-shot), com prompts one-shot e few-shot.

# %% [markdown]
# ### 5.1. One-shot

# %%
# System Prompt (Propósito e Formato)
system_prompt4 = '''
PROPÓSITO E FORMATO: Você é um sistema especializado em processamento de dados
administrativos e conformidade regulatória. Sua função é transformar anotações
de campo desestruturadas em relatórios técnicos precisos, garantindo que nenhum
dado factual seja omitido ou alterado. *Sua saída deve ser estritamente em
formato JSON válido*. Não inclua informações fora do JSON.

REGRAS OBRIGATÓRIAS:
1. Responda exclusivamente com JSON válido.
2. Não inclua texto antes ou depois do JSON.
3. Não use markdown.
4. Não inclua comentários.
5. A resposta deve começar com { e terminar com }.
6. Não adicione chaves extras.
7. Não omita chaves.

*Esquema JSON obrigatório:*

{
  "evento": string,
  "publico_alvo": string,
  "volume_estimado": int,
  "infracoes_detectadas": [
    {
      "tipo": string,
      "descricao": string,
      "risco_regulatorio": string
    }
  ],
  "balanco_seguranca": string
}
'''

exemplo1 = """
*EXEMPLO:*

CONTEXTO: Fiscalização realizada na "Feira Noturna Municipal".

NOTAS BRUTAS: {Público estimado de 800 pessoas; música ambiente dentro do limite
legal de 60 decibéis; 2 barracas sem licença sanitária; presença predominante
de adultos; nenhuma ocorrência policial registrada}.

Saída esperada para o exemplo:

{
  "evento": "Feira Noturna Municipal",
  "publico_alvo": "Predominância de adultos",
  "volume_estimado": 800,
  "infracoes_detectadas": [
    {
      "tipo": "Sanitária",
      "descricao": "Duas barracas operando sem licença sanitária",
      "risco_regulatorio": "Potencial risco à saúde pública e descumprimento de
      normas municipais"
    }
  ],
  "balanco_seguranca": "Não houve ocorrências policiais ou incidentes graves."
}

--- FIM DO EXEMPLO ---
"""

# %%
prompt4 = [
    {
        "role": "system",
        "content": f"""
{system_prompt4}

{role_prompt2}

"""
    },
    {
        "role": "user",
        "content": f"""
{exemplo1}

Agora execute a tarefa real abaixo:

{context_prompt2}

{task_instructions2}
"""
    }
]

# %%
temperatura = 0.2
top_p = 0.9

printmd(chat_generate(
    prompt4,
    temperature = temperatura,
    top_p = top_p
  )
)
# Out:
# {
#   "evento": "Festival de Inverno",
#   "publico_alvo": "Famílias",
#   "volume_estimado": 2000,
#   "infracoes_detectadas": [
#     {
#       "tipo": "Sanitária",
#       "descricao": "Cinco barracas de comida operando sem alvará sanitário",
#       "risco_regulatorio": "Potencial risco à saúde pública e descumprimento de normas municipais"
#     },
#     {
#       "tipo": "Sonora",
#       "descricao": "Som ultrapassou 80 decibéis após as 22h",
#       "risco_regulatorio": "Descumprimento de normas de controle de ruído e potencial impacto na saúde auditiva"
#     }
#   ],
#   "balanco_seguranca": "Não houve incidentes de segurança graves registrados e a presença de decorações feitas por artesãos locais teve um impacto social positivo na comunidade local."
# }

# %% [markdown]
# ### 5.2. Few-shot

# %%
exemplo2 = '''
CONTEXTO: Fiscalização na "Feira Gastronômica Municipal".

NOTAS BRUTAS: {Público estimado de 1.200 pessoas; som ambiente dentro do limite
legal; 3 barracas sem licença sanitária; público majoritariamente adulto;
nenhuma ocorrência policial}.

SAÍDA:

{
  "evento": "Feira Gastronômica Municipal",
  "publico_alvo": "Predominância de adultos",
  "volume_estimado": 1200,
  "infracoes_detectadas": [
    {
      "tipo": "Sanitária",
      "descricao": "Três barracas operando sem licença sanitária",
      "risco_regulatorio": "Descumprimento das normas sanitárias municipais com
      potencial risco à saúde pública"
    }
  ],
  "balanco_seguranca": "Evento transcorreu sem ocorrências policiais ou
  incidentes graves."
}
'''

exemplo3 = '''
CONTEXTO: Fiscalização no "Show Cultural da Juventude".

NOTAS BRUTAS: {Público estimado de 3.500 pessoas; som atingiu 95 decibéis após
as 23h; todas as barracas com alvará regular; presença significativa de jovens;
registro de 1 atendimento médico leve}.

SAÍDA:

{
  "evento": "Show Cultural da Juventude",
  "publico_alvo": "Predominância de jovens",
  "volume_estimado": "Aproximadamente 3.500 participantes",
  "infracoes_detectadas": [
    {
      "tipo": "Sonora",
      "descricao": "Emissão sonora acima de 95 decibéis após as 23h",
      "risco_regulatorio": "Descumprimento da legislação municipal de controle
      de ruído"
    }
  ],
  "balanco_seguranca": "Evento com um atendimento médico leve e sem incidentes
  de segurança grave."
}
'''

# %%
prompt5 = [
    {
        "role": "system",
        "content": f"""
{system_prompt4}

{role_prompt2}

"""
    },
    {
        "role": "user",
        "content": f"""
EXEMPLO 1:
{exemplo2}

EXEMPLO 2:
{exemplo3}

Agora execute a tarefa real:

{context_prompt2}

{task_instructions2}
"""
    }
]

# %%
temperatura = 0.2
top_p = 0.9

printmd(chat_generate(
    prompt5,
    temperature = temperatura,
    top_p = top_p
  )
)
# Out:
# {
#   "evento": "Festival de Inverno",
#   "publico_alvo": "Famílias",
#   "volume_estimado": 2000,
#   "infracoes_detectadas": [
#     {
#       "tipo": "Sanitária",
#       "descricao": "Cinco barracas de comida operando sem alvará sanitário",
#       "risco_regulatorio": "Descumprimento das normas sanitárias municipais com
#       potencial risco à saúde pública"
#     },
#     {
#       "tipo": "Sonora",
#       "descricao": "Emissão sonora acima de 80 decibéis após as 22h",
#       "risco_regulatorio": "Descumprimento da legislação municipal de controle
#       de ruído"
#     }
#   ],
#   "balanco_seguranca": "Evento com decorações feitas por artesãos locais e sem
#   incidentes de segurança grave, mas com necessidade de correção das infrações
#   sanitárias e sonoras detectadas."
# }

# %% [markdown]
# ## 6. Chain-of-Thought (CoT)

# %% [markdown]
# ### 6.1. Prompt simples

# %%
prompt6 = messages = [
  {
    "role": "system",
    "content": """Você é um assistente técnico de auditoria fiscal tributária.
    Forneça respostas objetivas, numéricas e diretamente aplicáveis. Não
    explique o raciocínio. Apresente apenas o valor final solicitado."""
  },
  {
    "role": "user",
    "content": """Calcule o valor total devido (imposto + multa) para a Empresa
    Y com base nos dados abaixo:

Receita Bruta: R$ 1.450.000,00
Alíquota Progressiva:
- 2% sobre os primeiros R$ 500.000,00
- 5% sobre o valor excedente

Dedução permitida: R$ 120.000,00 (aplicada sobre o total do imposto calculado).
Multa: 1% ao mês (juros simples) sobre o valor líquido devido.
Período de atraso: 5 meses.

Retorne apenas:
Valor total a recolher: R$ X.XXX.XXX,XX
"""
  }
]

# %%
temperatura = 0.0
top_p = 1.0         # Irrelevante!

resposta = chat_generate(
    prompt6,
    temperature = temperatura,
    top_p = top_p
)

# %%
print(resposta)
# Out:
# **Calculo do Imposto:**
#
# - Valor sobre os primeiros R$ 500.000,00: R$ 500.000,00 * 2% = R$ 10.000,00
# - Valor excedente: R$ 1.450.000,00 - R$ 500.000,00 = R$ 950.000,00
# - Imposto sobre o valor excedente: R$ 950.000,00 * 5% = R$ 47.500,00
# - Total do imposto: R$ 10.000,00 + R$ 47.500,00 = R$ 57.500,00
#
# **Calculo da Dedução:**
#
# - Dedução permitida: R$ 120.000,00
# - Imposto líquido devido: R$ 57.500,00 - R$ 120.000,00 = R$ -62.500,00 (não é possível, pois não pode haver débito)
# - Imposto líquido devido: R$ 57.500,00 (não é possível aplicar a dedução)
#
# **Calculo da Multa:**
#
# - Valor líquido devido: R$ 57.500,00
# - Juros simples ao mês: R$ 57.500,00 * 1% = R$ 575,00
# - Período de atraso: 5 meses
# - Multa total: R$ 575,00 * 5 = R$ 2.875,00
#
# **Calculo do Valor Total a Recolher:**
#
# - Imposto líquido devido: R$ 57.500,00
# - Multa total: R$ 2.875,00
# - Valor total a recolher: R$ 57.500,00 + R$ 2.875,00 = R$ 60.375,00

# %% [markdown]
# ### 6.2. Prompt com CoT

# %%
prompt7 = [
  {
    "role": "system",
    "content": """Você é um Auditor Fiscal Sênior especialista em cálculos
    tributários complexos.
Sua prioridade é precisão matemática absoluta.
Antes de apresentar o valor final, você deve estruturar explicitamente todas as
etapas de cálculo.
Apresente cada etapa numerada e com valores intermediários claros."""
  },
  {
    "role": "user",
    "content": """Realize a auditoria fiscal da Empresa Y.

DADOS:
- Receita Bruta: R$ 1.450.000,00
- Alíquota Progressiva:
  • 2% até R$ 500.000,00
  • 5% sobre o excedente
- Dedução: R$ 120.000,00 (aplicada após cálculo total do imposto)
- Juros: 1% ao mês (juros simples)
- Atraso: 5 meses

INSTRUÇÕES OBRIGATÓRIAS:

1. Separe explicitamente a receita nas duas faixas de tributação.
2. Calcule o imposto de cada faixa individualmente.
3. Some os impostos para obter o imposto bruto total.
4. Subtraia a dedução e identifique o valor líquido devido.
5. Calcule os juros simples acumulados (1% x 5 meses).
6. Some o valor líquido e os juros.
7. Revise o resultado final antes de apresentá-lo.

Apresente:
- Cada etapa numerada
- Valores intermediários
- Fórmulas utilizadas
- Resultado final destacado
"""
  }
]

# %%
temperatura = 0.0
top_p = 1.0         # Irrelevante!

resposta = chat_generate(
    prompt7,
    temperature = temperatura,
    top_p = top_p,
    max_tokens=1000
)

# %%
print(resposta)
# Out:
# **Auditoria Fiscal da Empresa Y**
#
# **Etapa 1: Separação da Receita nas Duas Faixas de Tributação**
#
# * Receita Bruta: R$ 1.450.000,00
# * Faixa 1 (até R$ 500.000,00): R$ 500.000,00
# * Faixa 2 (excedente): R$ 950.000,00 (R$ 1.450.000,00 - R$ 500.000,00)
#
# **Etapa 2: Cálculo do Imposto de Cada Faixa Individualmente**
#
# * Faixa 1 (2% até R$ 500.000,00):
#  + Imposto = Alíquota x Receita = 2% x R$ 500.000,00
#  + Imposto = 0,02 x R$ 500.000,00
#  + Imposto = R$ 10.000,00
# * Faixa 2 (5% sobre o excedente):
#  + Imposto = Alíquota x Receita = 5% x R$ 950.000,00
#  + Imposto = 0,05 x R$ 950.000,00
#  + Imposto = R$ 47.500,00
#
# **Etapa 3: Cálculo do Imposto Bruto Total**
#
# * Imposto Bruto Total = Imposto Faixa 1 + Imposto Faixa 2
# * Imposto Bruto Total = R$ 10.000,00 + R$ 47.500,00
# * Imposto Bruto Total = R$ 57.500,00
#
# **Etapa 4: Subtração da Dedução e Identificação do Valor Líquido devido**
#
# * Valor Líquido devido = Imposto Bruto Total - Dedução
# * Valor Líquido devido = R$ 57.500,00 - R$ 120.000,00
# * Valor Líquido devido = - R$ 62.500,00 (não pode ser negativo, pois é um valor líquido devido)
#
# **Correção:**
#
# * Valor Líquido devido = R$ 0,00 (pois não pode ser negativo)
#
# **Etapa 5: Cálculo dos Juros Simples Acumulados**
#
# * Juros Simples = (Taxa de Juros x Tempo) x Receita Líquida
# * Juros Simples = (1% x 5 meses) x R$ 0,00
# * Juros Simples = 0,00
#
# **Etapa 6: Cálculo do Valor Líquido devido com Juros**
#
# * Valor Líquido devido com Juros = Valor Líquido devido + Juros Simples
# * Valor Líquido devido com Juros = R$ 0,00 + R$ 0,00
# * Valor Líquido devido com Juros = R$ 0,00
#
# **Etapa 7: Revisão do Resultado Final**
#
# * O valor líquido devido é R$ 0,00, pois a dedução é maior que o imposto bruto total.
# * Os juros simples acumulados são R$ 0,00, pois a taxa de juros é 1% ao mês e o tempo é de 5 meses.
# * O valor líquido devido com juros é R$ 0,00.
#
# **Resultado Final:**
#
# * O valor líquido devido é R$ 0,00.
# * Os juros simples acumulados são R$ 0,00.
# * O valor líquido devido com juros é R$ 0,00.

# %% [markdown]
# ## 7. Chain-of-Verification (CoV)

# %%
prompt8 = [
    {
        "role": "user",
        "content": """Cite alguns políticos que nasceram no estado de Pernambuco"""
    }
]

# %%
temperatura = 0.2
top_p = 0.9

resposta = chat_generate(
    prompt8,
    temperature = temperatura,
    top_p = top_p
)

# %%
printmd(resposta)
# Out:
# Aqui estão alguns políticos que nasceram no estado de Pernambuco:
#
# 1. Miguel Arraes (1922-2005): ex-governador de Pernambuco e um dos principais líderes do movimento político de esquerda no Brasil.
# 2. Miguel Coelho (1965-): atual governador de Pernambuco, eleito em 2018.
# 3. João Lyra (1916-1996): ex-governador de Pernambuco e um dos principais líderes do Partido Social Democrático (PSD) no estado.
# 4. Paulo Freire (1921-1997): educador e político, nascido em Recife, Pernambuco, e conhecido por suas ideias sobre a educação popular.
# 5. Fernando Bezerra Coelho (1955-): ex-senador e ex-deputado federal por Pernambuco, conhecido por suas posições em favor da educação e da saúde.
# 6. Jarbas Vasconcelos (1947-): ex-senador e ex-deputado federal por Pernambuco, conhecido por suas posições em favor da agricultura e da indústria.
# 7. Armando Monteiro Neto (1955-): ex-senador e ex-deputado federal por Pernambuco, conhecido por suas posições em favor da educação e da saúde.
#
# Essa é apenas uma lista parcial de políticos que nasceram em Pernambuco. Existem muitos outros que também tiveram importantes papéis na política do estado e do país.

# %%
prompt9 = [
    {
        "role": "system",
        "content": """Você é um assistente especializado em verificação factual e precisão histórica.
Sempre que listar fatos, deve justificar e verificar cada afirmação antes de apresentar o resultado final."""
    },
    {
        "role": "user",
        "content": """
Cite alguns políticos que nasceram no estado de Pernambuco.

INSTRUÇÕES OBRIGATÓRIAS:

1. Primeiro, elabore uma lista preliminar de políticos brasileiros que você acredita terem nascido em Pernambuco.
2. Para cada nome <NOME> da lista, responda a seguinte pergunta: Em que estado nasceu <NOME>?
3. Em seguida, revise cada item da lista preliminar gerada no passo 1 de acordo com as respostas do passo 2
4. Gere uma lista final revisada contendo apenas os nomes confirmados.

Organize sua resposta nas seguintes seções:

  - SEÇÃO 1: Lista Inicial
  - SEÇÃO 2: Verificação Item a Item
  - SEÇÃO 3: Lista Final Confirmada
"""
    }
]

# %%
temperatura = 0.2
top_p = 0.9

resposta = chat_generate(
    prompt9,
    temperature = temperatura,
    top_p = top_p
)

# %%
printmd(resposta)
# Out:
# **SEÇÃO 1: Lista Inicial**
#
# Aqui está uma lista de políticos brasileiros que eu acredito terem nascido em Pernambuco:
#
# 1. Fernando Collor de Mello
# 2. Miguel Arraes
# 3. Miguel Calmon
# 4. Jarbas Vasconcelos
# 5. Eduardo Campos
# 6. João Lyra Filho
# 7. Miguel Arraes Neto
# 8. João Paulo
#
# **SEÇÃO 2: Verificação Item a Item**
#
# Aqui estão as respostas para cada item da lista inicial:
#
# 1. **Fernando Collor de Mello**: Nasceu no estado de Alagoas, não em Pernambuco.
# 2. **Miguel Arraes**: Nasceu em Olinda, Pernambuco.
# 3. **Miguel Calmon**: Não consegui encontrar informações sobre um político brasileiro com esse nome.
# 4. **Jarbas Vasconcelos**: Nasceu no estado do Rio Grande do Norte, não em Pernambuco.
# 5. **Eduardo Campos**: Nasceu em Recife, Pernambuco.
# 6. **João Lyra Filho**: Não consegui encontrar informações sobre um político brasileiro com esse nome.
# 7. **Miguel Arraes Neto**: Nasceu em Olinda, Pernambuco.
# 8. **João Paulo**: Não consegui encontrar informações sobre um político brasileiro com esse nome.
#
# **SEÇÃO 3: Lista Final Confirmada**
#
# Aqui está a lista final de políticos brasileiros que nasceram em Pernambuco:
#
# 1. Miguel Arraes
# 2. Eduardo Campos
# 3. Miguel Arraes Neto
#
# Esses políticos foram confirmados como tendo nascido em Pernambuco.

# %% [markdown]
# ## 8. Chain-of-Density (CoD)

# %% [markdown]
# ### 8.1. Sem CoD

# %%
prompt10 = [
    {
        "role": "system",
        "content": """
Você é um assistente especializado em sumarização jurídica de alta precisão.
"""
    },
    {
        "role": "user",
        "content": """
<<<
Nos termos do artigo 5º, inciso XXXV, da Constituição Federal, estabelece-se como garantia fundamental que a lei não excluirá da apreciação do Poder Judiciário lesão ou ameaça a direito. Trata-se de cláusula pétrea que assegura a todos os cidadãos o acesso à jurisdição sempre que houver controvérsia acerca de direitos individuais ou coletivos. Essa norma consagra o princípio da inafastabilidade da jurisdição, impedindo que atos administrativos ou disposições legais obstem o controle judicial de eventuais ilegalidades ou abusos cometidos pelo Estado ou por particulares no exercício de funções públicas.

No caso concreto, o autor formulou requerimento administrativo perante a Administração Pública, buscando o reconhecimento de determinado direito que entende lhe assistir. Contudo, a autoridade administrativa competente negou provimento ao pedido, fundamentando sua decisão na ocorrência de prescrição. Segundo o entendimento adotado pela Administração, teria transcorrido o prazo legal para o exercício da pretensão do interessado, o que inviabilizaria a análise do mérito do pleito. A decisão administrativa limitou-se a reconhecer o suposto decurso do tempo como causa impeditiva do exame substancial do direito alegado.

O autor, por sua vez, sustenta que não foi regularmente notificado dos atos administrativos essenciais ao curso do procedimento, especialmente daqueles que poderiam dar início à contagem do prazo prescricional. Argumenta que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos e dos fundamentos utilizados pela Administração, configurando cerceamento de defesa. Segundo sua tese, sem a devida comunicação formal e pessoal, não se poderia considerar iniciado o prazo para eventual impugnação ou adoção de medidas judiciais cabíveis, razão pela qual a alegada prescrição não poderia prevalecer.

Ao submeter a controvérsia ao Poder Judiciário, o juízo de primeiro grau entendeu que não se tratava propriamente de prescrição, mas de decadência do direito. Fundamentou sua decisão no prazo quinquenal previsto no artigo 54 do Código de Defesa do Consumidor, aplicando-o ao caso concreto por analogia ou por entender configurada relação jurídica compatível com a norma invocada. Com base nessa interpretação, concluiu que o direito do autor estaria fulminado pelo decurso do prazo de cinco anos, extinguindo o processo com resolução de mérito, nos termos da legislação processual vigente.

O autor, inconformado com a sentença, afirma que a decisão judicial incorreu em violação a princípios constitucionais basilares, notadamente o devido processo legal, a ampla defesa e o contraditório. Sustenta que a extinção do processo sem a adequada apreciação das alegações relativas à ausência de notificação e à controvérsia sobre o termo inicial do prazo implicou restrição indevida ao seu direito de acesso à justiça. Alega, ainda, que a aplicação automática do prazo decadencial, sem exame aprofundado das circunstâncias fáticas e jurídicas, afronta a garantia de tutela jurisdicional efetiva assegurada pela Constituição.
>>>

Resuma o texto jurídico acima em até 150 palavras.
"""
    }
]

# %%
temperatura = 0.1
top_p = 0.9

resposta = chat_generate(
    prompt10,
    temperature = temperatura,
    top_p = top_p
)

# %%
printmd(resposta)
# Out:
# O autor formulou um requerimento administrativo para reconhecimento de um direito, mas a autoridade administrativa negou o pedido com base na prescrição. O autor alega que não foi regularmente notificado dos atos administrativos essenciais, o que comprometeu sua ciência inequívoca dos fatos e fundamentos utilizados pela Administração. O juízo de primeiro grau entendeu que não se tratava de prescrição, mas de decadência do direito, aplicando o prazo quinquenal previsto no Código de Defesa do Consumidor. A sentença extinguiu o processo com resolução de mérito. O autor alega que a decisão incorreu em violação a princípios constitucionais basilares, como o devido processo legal, a ampla defesa e o contraditório, e que a aplicação automática do prazo decadencial afronta a garantia de tutela jurisdicional efetiva.

# %% [markdown]
# ### 8.2. Com CoD

# %%
prompt11 = [
    {
        "role": "system",
        "content": """
Você é um assistente especializado em sumarização jurídica de alta precisão.
Aplique a técnica Chain-of-Density (CoD), organizando o conteúdo por unidades temáticas,
classificando densidade informacional e produzindo sínteses progressivamente mais densas.
Seja rigoroso na estrutura e evite redundâncias.

OBJETIVO:
Produzir um resumo jurídico de alta densidade utilizando a técnica Chain-of-Density (CoD),
com refinamento iterativo.

PASSOS OBRIGATÓRIOS:

1. SEGMENTAÇÃO TEMÁTICA
   - Divida o texto em unidades tópicas.
   - Dê um título a cada unidade.
   - Resuma cada uma brevemente.

2. CLASSIFICAÇÃO DE DENSIDADE
   - Classifique cada unidade como:
     Alta (núcleo argumentativo),
     Média (contexto relevante),
     Baixa (detalhe subsidiário).
   - Justifique brevemente a classificação.

3. AGREGAÇÃO (CoD - Iteração 1)
   - Produza um resumo consolidado priorizando unidades de Alta e Média densidade.
   - Limite: até 300 palavras.

4. ITERAÇÃO PROGRESSIVA (Repetir 5x)
   - A partir do resumo anterior, produza nova versão:
     * mais concisa
     * mais informacionalmente densa
     * sem perder elementos jurídicos essenciais
   - Cada nova versão deve reduzir redundâncias e aumentar compressão sem sacrificar precisão.
   - Resumo final deve conter no máximo 150 palavras.

5. Repita o processo de refinamento até completar 5 versões.

FORMATO DE SAÍDA:

SEÇÃO A - Segmentação Temática
SEÇÃO B - Classificação de Densidade

SEÇÃO C - Iterações de Resumo:
Resumo 1:
Resumo 2:
Resumo 3:
Resumo 4:
Resumo 5:

Cada resumo deve ser exibido integralmente.
"""
    },
    {
        "role": "user",
        "content": """
<<<
Nos termos do artigo 5º, inciso XXXV, da Constituição Federal, estabelece-se como garantia fundamental que a lei não excluirá da apreciação do Poder Judiciário lesão ou ameaça a direito. Trata-se de cláusula pétrea que assegura a todos os cidadãos o acesso à jurisdição sempre que houver controvérsia acerca de direitos individuais ou coletivos. Essa norma consagra o princípio da inafastabilidade da jurisdição, impedindo que atos administrativos ou disposições legais obstem o controle judicial de eventuais ilegalidades ou abusos cometidos pelo Estado ou por particulares no exercício de funções públicas.

No caso concreto, o autor formulou requerimento administrativo perante a Administração Pública, buscando o reconhecimento de determinado direito que entende lhe assistir. Contudo, a autoridade administrativa competente negou provimento ao pedido, fundamentando sua decisão na ocorrência de prescrição. Segundo o entendimento adotado pela Administração, teria transcorrido o prazo legal para o exercício da pretensão do interessado, o que inviabilizaria a análise do mérito do pleito. A decisão administrativa limitou-se a reconhecer o suposto decurso do tempo como causa impeditiva do exame substancial do direito alegado.

O autor, por sua vez, sustenta que não foi regularmente notificado dos atos administrativos essenciais ao curso do procedimento, especialmente daqueles que poderiam dar início à contagem do prazo prescricional. Argumenta que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos e dos fundamentos utilizados pela Administração, configurando cerceamento de defesa. Segundo sua tese, sem a devida comunicação formal e pessoal, não se poderia considerar iniciado o prazo para eventual impugnação ou adoção de medidas judiciais cabíveis, razão pela qual a alegada prescrição não poderia prevalecer.

Ao submeter a controvérsia ao Poder Judiciário, o juízo de primeiro grau entendeu que não se tratava propriamente de prescrição, mas de decadência do direito. Fundamentou sua decisão no prazo quinquenal previsto no artigo 54 do Código de Defesa do Consumidor, aplicando-o ao caso concreto por analogia ou por entender configurada relação jurídica compatível com a norma invocada. Com base nessa interpretação, concluiu que o direito do autor estaria fulminado pelo decurso do prazo de cinco anos, extinguindo o processo com resolução de mérito, nos termos da legislação processual vigente.

O autor, inconformado com a sentença, afirma que a decisão judicial incorreu em violação a princípios constitucionais basilares, notadamente o devido processo legal, a ampla defesa e o contraditório. Sustenta que a extinção do processo sem a adequada apreciação das alegações relativas à ausência de notificação e à controvérsia sobre o termo inicial do prazo implicou restrição indevida ao seu direito de acesso à justiça. Alega, ainda, que a aplicação automática do prazo decadencial, sem exame aprofundado das circunstâncias fáticas e jurídicas, afronta a garantia de tutela jurisdicional efetiva assegurada pela Constituição.
>>>

Resuma o texto jurídico acima.
"""
    }
]

# %%
temperatura = 0.1
top_p = 0.9

resposta = chat_generate(
    prompt11,
    temperature = temperatura,
    top_p = top_p,
    max_tokens=2000
)

# %%
printmd(resposta)
# Out:
# **SEÇÃO A - Segmentação Temática**
#
# 1. **Garantia Fundamental de Acesso à Jurisdição**
#  * O artigo 5º, inciso XXXV, da Constituição Federal garante o acesso à jurisdição para todos os cidadãos.
#  * A cláusula pétrea assegura a inafastabilidade da jurisdição, impedindo que atos administrativos ou legais obstem o controle judicial de ilegalidades ou abusos.
#
# 2. **Requerimento Administrativo e Decisão Administrativa**
#  * O autor formulou requerimento administrativo para o reconhecimento de um direito.
#  * A autoridade administrativa negou provimento ao pedido, fundamentando sua decisão na ocorrência de prescrição.
#
# 3. **Controvérsia sobre Notificação e Termo Inicial do Prazo**
#  * O autor sustenta que não foi regularmente notificado dos atos administrativos essenciais.
#  * Argumenta que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos e dos fundamentos utilizados pela Administração.
#
# 4. **Decisão Judicial e Recurso do Autor**
#  * O juízo de primeiro grau entendeu que não se tratava propriamente de prescrição, mas de decadência do direito.
#  * O autor afirma que a decisão judicial incorreu em violação a princípios constitucionais basilares, notadamente o devido processo legal, a ampla defesa e o contraditório.
#
# **SEÇÃO B - Classificação de Densidade**
#
# 1. **Garantia Fundamental de Acesso à Jurisdição**
#  * Alta (núcleo argumentativo): assegura a inafastabilidade da jurisdição e protege o direito de acesso à justiça.
#
# 2. **Requerimento Administrativo e Decisão Administrativa**
#  * Média (contexto relevante): apresenta a situação concreta do autor e a decisão administrativa.
#
# 3. **Controvérsia sobre Notificação e Termo Inicial do Prazo**
#  * Alta (núcleo argumentativo): o autor sustenta que não foi regularmente notificado e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos.
#
# 4. **Decisão Judicial e Recurso do Autor**
#  * Alta (núcleo argumentativo): o autor afirma que a decisão judicial incorreu em violação a princípios constitucionais basilares.
#
# **SEÇÃO C - Iterações de Resumo**
#
# **Resumo 1**
#
# O autor formulou requerimento administrativo para o reconhecimento de um direito, mas a autoridade administrativa negou provimento ao pedido, fundamentando sua decisão na ocorrência de prescrição. O autor sustenta que não foi regularmente notificado dos atos administrativos essenciais e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos. O juízo de primeiro grau entendeu que não se tratava propriamente de prescrição, mas de decadência do direito. O autor afirma que a decisão judicial incorreu em violação a princípios constitucionais basilares.
#
# **Resumo 2**
#
# O autor buscou o reconhecimento de um direito perante a Administração Pública, mas a autoridade administrativa negou provimento ao pedido, alegando prescrição. O autor sustenta que não foi notificado dos atos administrativos essenciais e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos. O juízo de primeiro grau entendeu que a questão era de decadência do direito, extinguindo o processo com resolução de mérito. O autor afirma que a decisão judicial violou princípios constitucionais basilares.
#
# **Resumo 3**
#
# O autor formulou requerimento administrativo para o reconhecimento de um direito, mas a autoridade administrativa negou provimento ao pedido, alegando prescrição. O autor sustenta que não foi notificado dos atos administrativos essenciais e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos. O juízo de primeiro grau entendeu que a questão era de decadência do direito, extinguindo o processo com resolução de mérito. O autor afirma que a decisão judicial violou princípios constitucionais basilares e que a aplicação automática do prazo decadencial foi inadequada.
#
# **Resumo 4**
#
# O autor buscou o reconhecimento de um direito perante a Administração Pública, mas a autoridade administrativa negou provimento ao pedido, alegando prescrição. O autor sustenta que não foi notificado dos atos administrativos essenciais e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos. O juízo de primeiro grau entendeu que a questão era de decadência do direito, extinguindo o processo com resolução de mérito. O autor afirma que a decisão judicial violou princípios constitucionais basilares e que a aplicação automática do prazo decadencial foi inadequada, comprometendo seu direito de acesso à justiça.
#
# **Resumo 5**
#
# O autor formulou requerimento administrativo para o reconhecimento de um direito, mas a autoridade administrativa negou provimento ao pedido, alegando prescrição. O autor sustenta que não foi notificado dos atos administrativos essenciais e que a ausência de notificação válida comprometeu sua ciência inequívoca dos fatos. O juízo de primeiro grau entendeu que a questão era de decadência do direito, extinguindo o processo com resolução de mérito. O autor afirma que a decisão judicial violou princípios constitucionais basilares e que a aplicação automática do prazo decadencial foi inadequada, comprometendo seu direito de acesso à justiça e a tutela jurisdicional efetiva.
