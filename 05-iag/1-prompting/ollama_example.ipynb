# %% [markdown]
# # Llama 3.2 3B Instruct - Exemplo com Ollama
#
# Este notebook demonstra como usar o modelo **Llama 3.2 3B Instruct** localmente via Ollama.

# %% [markdown]
# ## 1. Verificar se o Ollama está rodando

# %%
import requests

try:
    response = requests.get("http://localhost:11434")
    print(f"✅ Ollama rodando: {response.text.strip()}")
except Exception as e:
    print(f"❌ Ollama não está rodando. Erro: {e}")
    print(f"Execute o comando 'ollama serve'")
# Out:
# ✅ Ollama rodando: Ollama is running

# %% [markdown]
# ## 2. Listar modelos disponíveis

# %%
import subprocess

result = subprocess.run(["ollama", "list"], capture_output=True, text=True)
print(result.stdout)
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.2:3b    a80c4f17acd5    2.0 GB    13 days ago
# glm-5:cloud    c313cd065935    -         13 days ago

# %% [markdown]
# ## 3. Usar o modelo com a biblioteca `ollama`

# %%
import ollama

# Exemplo simples de chat
response = ollama.chat(
    model="llama3.2:3b",
    messages=[
        {"role": "user", "content": "Explique o que é Deep Learning em 3 frases."}
    ]
)

print(response["message"]["content"])
# Out:
# Deep Learning é uma sub-área da Inteligência Artificial (IA) que utiliza redes neurais complexas para processar e aprender a partir de grandes conjuntos de dados. Essa abordagem permite aos sistemas aprender a partir de exemplos sem precisar ser explicitamente programados, tornando-a extremamente flexível e eficiente em tarefas como reconhecimento de imagem, geração de texto e processamento de linguagem natural. Ao contrário de outros métodos de aprendizado de máquina, o Deep Learning não depende de regras pré-determinadas para aprender, mas sim de padrões ocultos nos dados.

# %% [markdown]
# ## 4. Chat com contexto (múltiplas mensagens)

# %%
messages = [
    {"role": "system", "content": "Você é um assistente especializado em IA. Seja conciso e técnico."},
    {"role": "user", "content": "Qual a diferença entre RNN e Transformer?"},
]

response = ollama.chat(model="llama3.2:3b", messages=messages)
print(response["message"]["content"])
# Out:
# RNN (Redes Neurais Recorrentes) e Transformer são dois tipos de redes neurais profundas usadas para processamento de linguagem natural, especialmente para tarefas como tradução automática e compreensão de texto.
#
# **Diferenças principais:**
#
# 1. **Arquitetura**: RNNs têm uma estrutura em caminhos forçados (sequence-to-sequence) que seguem a direção do tempo. Já o Transformer é baseado na atenção de ótima qualidade, utilizando apenas múltiplas camadas convolucionais.
# 2. **Atenção**: O Transformer utiliza a atenção de ator e agente para capturar relacionamentos entre sílabas ou palavras independentemente da ordem em que elas aparecem no texto, enquanto RNNs dependem na sequência temporal para processar o texto.
# ...

# %% [markdown]
# ## 5. Streaming (resposta em tempo real)

# %%
print("🤖 Llama 3.2: ", end="")
for chunk in ollama.chat(
    model="llama3.2:3b",
    messages=[{"role": "user", "content": "Liste 3 aplicações práticas de LLMs."}],
    stream=True
):
    print(chunk["message"]["content"], end="", flush=True)
print()
# Out:
# 🤖 Llama 3.2: Claro, aqui estão três aplicações práticas de LLMs (Modelos de Linguagem de Grande Escala):
#
# 1. **Assistentes Virtuais**: Os LLMs podem ser usados para criar assistentes virtuais que possam entender e responder a perguntas de forma mais inteligente. Por exemplo, o modelo de linguagem do Google Bard pode ser usado para criar um assistente virtual que possa responder a perguntas de forma mais precisa e eficiente.
#
# 2. **Generação de Conteúdo**: Os LLMs podem ser usados para gerar conteúdo automático, como textos, imagens e vídeos. Por exemplo, o modelo de linguagem da Microsoft Azure Canva pode ser usado para criar uma ferramenta de design gráfico que possa gerar imagens personalizadas.
#
# 3. **Análise de Texto**: Os LLMs podem ser usados para analisar texto de forma mais precisa e eficiente. Por exemplo, o modelo de linguagem do IBM Watson pode ser usado para analisar sentimentos em textos, como avaliações de produtos ou comentários de clientes.
#
# ...

# %% [markdown]
# ## 6. Geração direta (sem chat)

# %%
# Modo generate (mais simples para tarefas únicas)
response = ollama.generate(
    model="llama3.2:3b",
    prompt="Complete: A inteligência artificial é"
)
print(response["response"])
# Out:
# A resposta correta seria:
#
# A inteligência artificial é uma técnica e área da informática que visa criar máquinas capazes de simular os processos do pensamento humano, permitindo que elas tomem decisões, aprendam com dados e se adaptem a novas situações.

# %% [markdown]
# ## 7. Parâmetros avançados

# %%
response = ollama.chat(
    model="llama3.2:3b",
    messages=[{"role": "user", "content": "Gerar um título criativo para um artigo sobre IA."}],
    options={
        "temperature": 0.9,
        "num_predict": 50,
        "top_p": 0.9,
        "top_k": 40,
    }
)
print(response["message"]["content"])
# Out:
# Claro! Aqui estão algumas sugestões de títulos criativos para um artigo sobre IA:
#
# 1. **"A Inteligência Artificial que nos Mudará a Vida"**
# 2. **"O Futuro da Intel

# %% [markdown]
# ## 8. Via API REST

# %%
import json

url = "http://localhost:11434/api/chat"
payload = {
    "model": "llama3.2:3b",
    "messages": [{"role": "user", "content": "Diga olá em português."}],
    "stream": False
}

response = requests.post(url, json=payload)
result = response.json()
print(result["message"]["content"])
# Out:
# Olá! Como posso ajudar você hoje?

# %% [markdown]
# ## 9. Informações do modelo

# %%
info = ollama.show("llama3.2:3b")
print(f"Modelo: llama3.2:3b")
print(f"Família: {info.get('details', {}).get('family', 'N/A')}")
print(f"Parâmetros: {info.get('details', {}).get('parameter_size', 'N/A')}")
print(f"Quantização: {info.get('details', {}).get('quantization_level', 'N/A')}")
# Out:
# Modelo: llama3.2:3b
# Família: llama
# Parâmetros: 3.2B
# Quantização: Q4_K_M
